# %%
# Set the input and output file paths
input_file = "kitti_labels.txt"
output_file = "eye_iris_labels.txt"

# Define the classes that we want to extract
classes = ["eye", "iris"]

# Open the input and output files
with open(input_file, "r") as f_in, open(output_file, "w") as f_out:
    # Loop over each line in the input file
    for line in f_in:
        # Split the line into its components
        components = line.strip().split(" ")
        
        # Extract the class and bounding box coordinates
        class_label = components[0]
        xmin = components[4]
        ymin = components[5]
        xmax = components[6]
        ymax = components[7]
        
        # Check if the class is one of the classes we want to extract
        if class_label in classes:
            # Write the class and bounding box coordinates to the output file
            output_line = f"{xmin} {ymin} {xmax} {ymax}\n"
            f_out.write(output_line)

# %%
# Set the input and output file paths
input_file = ("D:/Academics/PHD Admission/IIT Kanpur/IITK SEM2/Project IITK1/Datasets/IRIS_Detection_Data/Results/Hardik_Face_Output_labels/merged.txt")
output_file = "D:/Academics/PHD Admission/IIT Kanpur/IITK SEM2/Project IITK1/Datasets/IRIS_Detection_Data/Results/Hardik_Face_Output_labels/coordinates_merged.txt"

# Define the classes that we want to extract
classes = ["eye", "iris"]

# Open the input and output files
with open(input_file, "r") as f_in, open(output_file, "w") as f_out:
    # Write the header line
    f_out.write("class, xmin, ymin, xmax, ymax\n")
    
    # Loop over each class
    for class_label in classes:
        # Loop over each line in the input file
        for line in f_in:
            # Split the line into its components
            components = line.strip().split(" ")
            
            # Extract the object class and bounding box coordinates
            object_class = components[0]
            xmin = components[4]
            ymin = components[5]
            xmax = components[6]
            ymax = components[7]
            
            # Check if the object class is the current class
            if object_class == class_label:
                # Write the bounding box coordinates to the output file
                output_line = f"{class_label}, {xmin}, {ymin}, {xmax}, {ymax}\n"
                f_out.write(output_line)
        
        # Reset the file pointer to the beginning of the input file
        f_in.seek(0)

# %%
import csv

# Open the input .txt file and read its contents
with open("D:/Academics/PHD Admission/IIT Kanpur/IITK SEM2/Project IITK1/Datasets/IRIS_Detection_Data/Results/Hardik_Face_Output_labels/coordinates_merged.txt", 'r') as f:
    content = f.readlines()

# Initialize lists to hold the center coordinates of the left and right eyes and irises
right_eye_centers = []
left_eye_centers = []
right_iris_centers = []
left_iris_centers = []

# Loop through each line in the file
for line in content:
    # Split the line by whitespace to extract the class name and bounding box coordinates
    line = line.strip().split()
    class_name = line[0]
    xmin, ymin, xmax, ymax = map(int, line[:])

    # Calculate the center coordinates of the bounding box
    center_x = (xmin + xmax) // 2
    center_y = (ymin + ymax) // 2

    # Determine which eye or iris this bounding box belongs to, and add its center coordinates to the appropriate list
    if class_name == 'eye':
        if len(right_eye_centers) == len(left_eye_centers):
            right_eye_centers.append((center_x, center_y))
        else:
            left_eye_centers.append((center_x, center_y))
    elif class_name == 'iris':
        if len(right_iris_centers) == len(left_iris_centers):
            right_iris_centers.append((center_x, center_y))
        else:
            left_iris_centers.append((center_x, center_y))

# Write the center coordinates to a CSV file
with open('D:/Academics/PHD Admission/IIT Kanpur/IITK SEM2/Project IITK1/Datasets/IRIS_Detection_Data/Results/Hardik_Face_Output_labels/coordinates_merged.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['right_eye_x', 'right_eye_y', 'left_eye_x', 'left_eye_y', 'right_iris_x', 'right_iris_y', 'left_iris_x', 'left_iris_y'])
    for i in range(len(right_eye_centers)):
        row = [right_eye_centers[i][0], right_eye_centers[i][1], left_eye_centers[i][0], left_eye_centers[i][1], right_iris_centers[i][0], right_iris_centers[i][1], left_iris_centers[i][0], left_iris_centers[i][1]]

# %%
# !pip install pupil-detectors

# %%
import cv2
from pupil_detectors import Detector2D

detector = Detector2D()

# read image as numpy array from somewhere, e.g. here from a file
img = cv2.imread("E:/Driver_Gaze_Data/P4320230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-39-06.829160-1-recordings/2023-05-28_18-01-05-82c6b903/exports/000/Eye0_Rotate_Frame/36248.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

result = detector.detect(gray)
ellipse = result["ellipse"]
print(ellipse)
# draw the ellipse outline onto the input image
# note that cv2.ellipse() cannot deal with float values
# also it expects the axes to be semi-axes (half the size)
cv2.ellipse(
   img,
   tuple(int(v) for v in ellipse["center"]),
   tuple(int(v / 2) for v in ellipse["axes"]),
   ellipse["angle"],
   0, 360, # start/end angle for drawing
   (0, 0, 255) # color (BGR): red
)
cv2.imshow("Image", img)
cv2.waitKey(0)
# Out:
# {'center': (0.0, 0.0), 'axes': (0.0, 0.0), 'angle': -90.0}
# -1

# %%
import cv2
from pupil_detectors import Detector2D

detector = Detector2D()

# Read image as a numpy array from somewhere, e.g., from a file
img = cv2.imread("E:/Driver_Gaze_Data/P4320230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-39-06.829160-1-recordings/2023-05-28_18-01-05-82c6b903/exports/000/Eye1_Rotate_Frame/36422.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply thresholding
_, thresholded = cv2.threshold(gray, 200, 200, cv2.THRESH_BINARY)

# Detect ellipse on the thresholded image
result = detector.detect(thresholded)
ellipse = result["ellipse"]
print(ellipse)

# Draw the ellipse outline onto the input image
cv2.ellipse(
    img,
    tuple(int(v) for v in ellipse["center"]),
    tuple(int(v / 2) for v in ellipse["axes"]),
    ellipse["angle"],
    0, 360,  # start/end angle for drawing
    (0, 0, 255)  # color (BGR): red
)

# Display the image
cv2.imshow("Image", img)
cv2.waitKey(0)
# Out:
# {'center': (0.0, 0.0), 'axes': (0.0, 0.0), 'angle': -90.0}
# -1

# %%
pip install wheel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wheel in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (0.37.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import csv
from pupil_detectors import Detector2D

# Initialize the detector
detector = Detector2D()

# Folder containing the images
folder_path = "/Users/apple/Downloads/Sem6/ugp/output/eyes0_rotated"

# Output CSV file path
output_csv_path = "/Users/apple/Downloads/Sem6/ugp/output/eyes0_results.csv"

# Open the CSV file for writing
with open(output_csv_path, 'w', newline='') as csvfile:
    fieldnames = ['filename', 'center_x', 'center_y', 'major_axis', 'minor_axis', 'angle']
    csv_writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # Write the header to the CSV file
    csv_writer.writeheader()

    # Iterate through all image files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg"):
            # Read the image
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Detect ellipse
            result = detector.detect(gray)
            ellipse = result["ellipse"]

            # Draw the ellipse
            cv2.ellipse(
                img,
                tuple(int(v) for v in ellipse["center"]),
                tuple(int(v / 2) for v in ellipse["axes"]),
                ellipse["angle"],
                0, 360,
                (0, 0, 255)
            )

            # Show the image with the ellipse
            cv2.imshow("Image", img)
            cv2.waitKey(0)

            # Write the results to the CSV file
            csv_writer.writerow({
                'filename': filename,
                'center_x': ellipse['center'][0],
                'center_y': ellipse['center'][1],
                'major_axis': ellipse['axes'][0],
                'minor_axis': ellipse['axes'][1],
                'angle': ellipse['angle']
            })

# Close the CSV file
csvfile.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 import cv2
#       3 import csv
# ----> 4 from pupil_detectors import Detector2D
#       6 # Initialize the detector
#       7 detector = Detector2D()
#
# ModuleNotFoundError: No module named 'pupil_detectors'

# %%
import os
import cv2
import csv
from pupil_detectors import Detector2D

# Initialize the detector
detector = Detector2D()

# Folder containing the images
folder_path = "C:/Users/Pavan Kumar Sharma/Downloads/pupil-cloud-download-2024-01-05T06-07-56.675903-1-recordings/2023-05-11_16-46-45-273bb776/Left_Eye_Rotate_Frames/"

# Output CSV file path
output_csv_path = "C:/Users/Pavan Kumar Sharma/Downloads/pupil-cloud-download-2024-01-05T06-07-56.675903-1-recordings/2023-05-11_16-46-45-273bb776/output_results.csv"

# Open the CSV file for writing in append mode
with open(output_csv_path, 'a', newline='') as csvfile:
    fieldnames = ['filename', 'center_x', 'center_y', 'major_axis', 'minor_axis', 'angle']
    csv_writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # If the file is empty, write the header
    if csvfile.tell() == 0:
        csv_writer.writeheader()

    # Iterate through all image files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg"):
            # Read the image
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Detect ellipse
            result = detector.detect(gray)
            ellipse = result["ellipse"]

            # Draw the ellipse
            cv2.ellipse(
                img,
                tuple(int(v) for v in ellipse["center"]),
                tuple(int(v / 2) for v in ellipse["axes"]),
                ellipse["angle"],
                0, 360,
                (0, 0, 255)
            )

            # Show the image with the ellipse
            cv2.imshow("Image", img)
            cv2.waitKey(0)

            # Write the results to the CSV file
            csv_writer.writerow({
                'filename': filename,
                'center_x': ellipse['center'][0],
                'center_y': ellipse['center'][1],
                'major_axis': ellipse['axes'][0],
                'minor_axis': ellipse['axes'][1],
                'angle': ellipse['angle']
            })

# Close the CSV file
csvfile.close()

# %% [markdown]
# # Pupil Detected

# %%
import os
import cv2
import csv
from pupil_detectors import Detector2D

# Initialize the detector
detector = Detector2D()

# Folder containing the input images
input_folder_path = "E:/Driver_Gaze_Data/P4320230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-39-06.829160-1-recordings/2023-05-28_18-01-05-82c6b903/exports/000/Eye0_Rotate_Frame/"

# Output folder path for images with ellipse drawn
output_folder_path = "E:/Driver_Gaze_Data/P4320230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-39-06.829160-1-recordings/2023-05-28_18-01-05-82c6b903/exports/000/Eye1_Pupil_Detected_Frame1/"

# Output CSV file path
output_csv_path = "E:/Driver_Gaze_Data/P4320230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-39-06.829160-1-recordings/2023-05-28_18-01-05-82c6b903/exports/000/Eye1_Pupil_Detected_Frame1/Eye1_output_results1.csv"

# Open the CSV file for writing
with open(output_csv_path, 'w', newline='') as csvfile:
    fieldnames = ['filename', 'center_x', 'center_y', 'major_axis', 'minor_axis', 'angle']
    csv_writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    # Write the header to the CSV file
    csv_writer.writeheader()

    # Iterate through all image files in the input folder
    for filename in os.listdir(input_folder_path):
        if filename.endswith(".jpg"):
            # Read the image
            img_path = os.path.join(input_folder_path, filename)
            img = cv2.imread(img_path)
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Detect ellipse
            result = detector.detect(gray)
            ellipse = result["ellipse"]

            # Draw the ellipse on the image
            cv2.ellipse(
                img,
                tuple(int(v) for v in ellipse["center"]),
                tuple(int(v / 2) for v in ellipse["axes"]),
                ellipse["angle"],
                0, 360,
                (0, 0, 255)
            )

            # Save the image with ellipse drawn to the output folder
            output_img_path = os.path.join(output_folder_path, filename)
            cv2.imwrite(output_img_path, img)

            # Write the results to the CSV file
            csv_writer.writerow({
                'filename': filename,
                'center_x': ellipse['center'][0],
                'center_y': ellipse['center'][1],
                'major_axis': ellipse['axes'][0],
                'minor_axis': ellipse['axes'][1],
                'angle': ellipse['angle']
            })

# Close the CSV file
csvfile.close()

# %%
# !pip install pye3d

# %%
import os
import cv2
import csv
from pupil_detectors import Detector2D

# %%
import argparse

import cv2
from pupil_detectors import Detector2D

from pye3d.detector_3d import CameraModel, Detector3D, DetectorMode


def main(eye_video_path):
    # create 2D detector
    detector_2d = Detector2D()
    # create pye3D detector
    camera = CameraModel(focal_length=561.5, resolution=[400, 400])
    detector_3d = Detector3D(camera=camera, long_term_mode=DetectorMode.blocking)
    # load eye video
    eye_video = cv2.VideoCapture(eye_video_path)
    # read each frame of video and run pupil detectors
    while eye_video.isOpened():
        frame_number = eye_video.get(cv2.CAP_PROP_POS_FRAMES)
        fps = eye_video.get(cv2.CAP_PROP_FPS)
        ret, eye_frame = eye_video.read()
        if ret:
            # read video frame as numpy array
            grayscale_array = cv2.cvtColor(eye_frame, cv2.COLOR_BGR2GRAY)
            # run 2D detector on video frame
            result_2d = detector_2d.detect(grayscale_array)
            result_2d["timestamp"] = frame_number / fps
            # pass 2D detection result to 3D detector
            result_3d = detector_3d.update_and_detect(result_2d, grayscale_array)
            ellipse_3d = result_3d["ellipse"]
            # draw 3D detection result on eye frame
            cv2.ellipse(
                eye_frame,
                tuple(int(v) for v in ellipse_3d["center"]),
                tuple(int(v / 2) for v in ellipse_3d["axes"]),
                ellipse_3d["angle"],
                0,
                360,  # start/end angle for drawing
                (0, 255, 0),  # color (BGR): red
            )
            # show frame
            cv2.imshow("eye_frame", eye_frame)
            # press esc to exit
            if cv2.waitKey(1) & 0xFF == 27:
                break
        else:
            break
    eye_video.release()
    cv2.destroyAllWindows()


if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument('E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/PI_left_v1_ps1.mp4')
    args = parser.parse_args()
    main(args.eye_video_path)

# %%
import argparse

import cv2
from pupil_detectors import Detector2D

from pye3d.detector_3d import CameraModel, Detector3D, DetectorMode


def main(eye_video_path):
    # create 2D detector
    detector_2d = Detector2D()
    # create pye3D detector
    camera = CameraModel(focal_length=561.5, resolution=[400, 400])
    detector_3d = Detector3D(camera=camera, long_term_mode=DetectorMode.blocking)
    # load eye video
    eye_video = cv2.VideoCapture(eye_video_path)
    # read each frame of video and run pupil detectors
    while eye_video.isOpened():
        frame_number = eye_video.get(cv2.CAP_PROP_POS_FRAMES)
        fps = eye_video.get(cv2.CAP_PROP_FPS)
        ret, eye_frame = eye_video.read()
        if ret:
            # read video frame as numpy array
            grayscale_array = cv2.cvtColor(eye_frame, cv2.COLOR_BGR2GRAY)
            # run 2D detector on video frame
            result_2d = detector_2d.detect(grayscale_array)
            result_2d["timestamp"] = frame_number / fps
            # pass 2D detection result to 3D detector
            result_3d = detector_3d.update_and_detect(result_2d, grayscale_array)
            ellipse_3d = result_3d["ellipse"]
            # draw 3D detection result on eye frame
            cv2.ellipse(
                eye_frame,
                tuple(int(v) for v in ellipse_3d["center"]),
                tuple(int(v / 2) for v in ellipse_3d["axes"]),
                ellipse_3d["angle"],
                0,
                360,  # start/end angle for drawing
                (0, 255, 0),  # color (BGR): red
            )
            # show frame
            cv2.imshow("eye_frame", eye_frame)
            # press esc to exit
            if cv2.waitKey(1) & 0xFF == 27:
                break
        else:
            break
    eye_video.release()
    cv2.destroyAllWindows()


if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/PI_left_v1_ps1.mp4")
    args = parser.parse_args()
    main(args.eye_video_path)

# %%
import argparse
import cv2
from pupil_detectors import Detector2D
from pye3d.detector_3d import CameraModel, Detector3D, DetectorMode

def main(eye_video_path):
    # create 2D detector
    detector_2d = Detector2D()
    # create pye3D detector
    camera = CameraModel(focal_length=561.5, resolution=[400, 400])
    detector_3d = Detector3D(camera=camera, long_term_mode=DetectorMode.blocking)
    # load eye video
    eye_video = cv2.VideoCapture(eye_video_path)
    # read each frame of video and run pupil detectors
    while eye_video.isOpened():
        frame_number = eye_video.get(cv2.CAP_PROP_POS_FRAMES)
        fps = eye_video.get(cv2.CAP_PROP_FPS)
        ret, eye_frame = eye_video.read()
        if ret:
            # read video frame as numpy array
            grayscale_array = cv2.cvtColor(eye_frame, cv2.COLOR_BGR2GRAY)
            # run 2D detector on video frame
            result_2d = detector_2d.detect(grayscale_array)
            result_2d["timestamp"] = frame_number / fps
            # pass 2D detection result to 3D detector
            result_3d = detector_3d.update_and_detect(result_2d, grayscale_array)
            ellipse_3d = result_3d["ellipse"]
            # draw 3D detection result on eye frame
            cv2.ellipse(
                eye_frame,
                tuple(int(v) for v in ellipse_3d["center"]),
                tuple(int(v / 2) for v in ellipse_3d["axes"]),
                ellipse_3d["angle"],
                0,
                360,  # start/end angle for drawing
                (0, 255, 0),  # color (BGR): red
            )
            # show frame
            cv2.imshow("eye_frame", eye_frame)
            # press esc to exit
            if cv2.waitKey(1) & 0xFF == 27:
                break
        else:
            break
    eye_video.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument("E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/PI_left_v1_ps1.mp4", help="Path to the eye video file")
    args = parser.parse_args()
    main(args.eye_video_path)

# %%
# !pip uninstall pye3d

# %%
import numpy as np
import csv

# Load the .npy file
data = np.load('E:/Driver_Gaze_Data/P1720230527D3/Eyetracker_Data/pupil-cloud-download-2024-01-17T06-39-11.844244-1-recordings/2023-05-27_11-12-55-adbbdcfd/eye1_timestamps.npy')

# Specify the path for the CSV file
csv_file_path = 'E:/Driver_Gaze_Data/P1720230527D3/Eyetracker_Data/pupil-cloud-download-2024-01-17T06-39-11.844244-1-recordings/2023-05-27_11-12-55-adbbdcfd/eye1_timestamps.csv'

# Save the data to the CSV file
np.savetxt(csv_file_path, data, delimiter=',')

# Optionally, you can customize the delimiter and other parameters as needed
# For example:
# np.savetxt(csv_file_path, data, delimiter=',', fmt='%.2f', header='Column1,Column2,Column3')

print(f"Conversion completed. Data saved to {csv_file_path}")
# Out:
# Conversion completed. Data saved to E:/Driver_Gaze_Data/P1720230527D3/Eyetracker_Data/pupil-cloud-download-2024-01-17T06-39-11.844244-1-recordings/2023-05-27_11-12-55-adbbdcfd/eye1_timestamps.csv

# %% [markdown]
# # Matching frames for human annotator (Eye frames)

# %%
import csv
import shutil
import os
from decimal import Decimal

def copy_frames(csv_path, source_folder, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Read CSV file
    with open(csv_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        next(csv_reader)  # Skip header row

        for row in csv_reader:
            front_came_time = Decimal(row[0])
            time_stamp = Decimal(row[2])
            frame_id = row[3]

            # Check if Front_Came_Time and Time_Stamp match up to two decimal places
            if front_came_time.quantize(Decimal('0.00')) == time_stamp.quantize(Decimal('0.00')):
                source_frame_path = os.path.join(source_folder, f"{frame_id}.jpg")

                # Check if the source frame file exists
                if os.path.exists(source_frame_path):
                    destination_frame_path = os.path.join(destination_folder, f"{frame_id}.jpg")

                    # Copy the frame to the destination folder
                    shutil.copy2(source_frame_path, destination_frame_path)
                    print(f"Frame {frame_id} copied to {destination_folder}")

# Example usage
csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
source_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye"
destination_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame"

copy_frames(csv_file_path, source_frames_folder, destination_frames_folder)

# %%
import csv
import shutil
import os
from decimal import Decimal, InvalidOperation

def copy_frames(csv_path, source_folder, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Read CSV file
    with open(csv_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        next(csv_reader)  # Skip header row

        for row in csv_reader:
            try:
                front_came_time = Decimal(row[0])
                time_stamp = Decimal(row[2])
            except InvalidOperation:
                print(f"Skipping row due to invalid decimal format: {row}")
                continue

            frame_id = row[3]

            # Check if Front_Came_Time and Time_Stamp match up to two decimal places
            if front_came_time.quantize(Decimal('0.00')) == time_stamp.quantize(Decimal('0.00')):
                source_frame_path = os.path.join(source_folder, f"frame_{frame_id}.jpg")

                # Check if the source frame file exists
                if os.path.exists(source_frame_path):
                    destination_frame_path = os.path.join(destination_folder, f"frame_{frame_id}.jpg")

                    # Copy the frame to the destination folder
                    shutil.copy2(source_frame_path, destination_frame_path)
                    print(f"Frame {frame_id} copied to {destination_folder}")

# Example usage
csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
source_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye"
destination_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame"

copy_frames(csv_file_path, source_frames_folder, destination_frames_folder)

# %%
import csv
import shutil
import os
from decimal import Decimal, InvalidOperation

def copy_frames(csv_path, source_folder, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Read CSV file
    with open(csv_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        header = next(csv_reader)  # Get header row

        # Find the column index for "Front_Came_Time"
        front_came_time_index = header.index("Front_Came_Time")
        time_stamp_index = header.index("Time_Stamp")
        frame_id_index = header.index("Frame_Id")

        for row in csv_reader:
            # Check if the row has values in the first column
            if row[front_came_time_index]:
                try:
                    front_came_time = Decimal(row[front_came_time_index])
                    time_stamp = Decimal(row[time_stamp_index])
                except InvalidOperation:
                    print(f"Skipping row due to invalid decimal format: {row}")
                    continue

                frame_id = row[frame_id_index]

                # Check if Front_Came_Time and Time_Stamp match up to two decimal places
                if front_came_time.quantize(Decimal('0.00')) == time_stamp.quantize(Decimal('0.00')):
                    source_frame_path = os.path.join(source_folder, f"{frame_id}.jpg")

                    # Check if the source frame file exists
                    if os.path.exists(source_frame_path):
                        destination_frame_path = os.path.join(destination_folder, f"{frame_id}.jpg")

                        # Copy the frame to the destination folder
                        shutil.copy2(source_frame_path, destination_frame_path)
                        print(f"Frame {frame_id} copied to {destination_folder}")

# Example usage
csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
source_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye"
destination_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame"
copy_frames(csv_file_path, source_frames_folder, destination_frames_folder)

# %%
import csv
import shutil
import os
from decimal import Decimal, InvalidOperation

def copy_frames(csv_path, source_folder, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Read CSV file
    with open(csv_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        header = next(csv_reader)  # Get header row

        # Find the column index for "Front_Came_Time"
        front_came_time_index = header.index("Front_Came_Time")
        time_stamp_index = header.index("Time_Stamp")
        frame_id_index = header.index("Frame_Id")

        for row in csv_reader:
            if row[front_came_time_index]:
                try:
                    front_came_time = Decimal(row[front_came_time_index])
                    time_stamp = Decimal(row[time_stamp_index])
                except InvalidOperation:
                    print(f"Skipping row due to invalid decimal format: {row}")
                    continue

                frame_id = row[frame_id_index]

                # Check if Front_Came_Time matches up to two decimal places
                if front_came_time.quantize(Decimal('0.00')) == time_stamp.quantize(Decimal('0.00')):
                    source_frame_path = os.path.join(source_folder, f"{frame_id}.jpg")
                    destination_frame_path = os.path.join(destination_folder, f"{frame_id}.jpg")

                    # Check if the source frame file exists
                    if os.path.exists(source_frame_path):
                        # Copy the frame to the destination folder
                        shutil.copy2(source_frame_path, destination_frame_path)
                        print(f"Frame {frame_id} copied to {destination_folder}")

# Example usage
csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
source_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye"
destination_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame"
copy_frames(csv_file_path, source_frames_folder, destination_frames_folder)

# %%
import csv
import shutil
import os
from decimal import Decimal, InvalidOperation

def copy_frames(csv_path, source_folder, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Read CSV file
    with open(csv_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        header = next(csv_reader)  # Get header row

        # Find the column index for "Front_Came_Time"
        front_came_time_index = header.index("Front_Came_Time")
        time_stamp_index = header.index("Time_Stamp")
        frame_id_index = header.index("Frame_Id")

        for row in csv_reader:
            if row[front_came_time_index]:
                try:
                    front_came_time = Decimal(row[front_came_time_index])
                    time_stamp = Decimal(row[time_stamp_index])
                except InvalidOperation:
                    print(f"Skipping row due to invalid decimal format: {row}")
                    continue

                frame_id = row[frame_id_index]

                # Check if Front_Came_Time matches up to two decimal places
                if front_came_time.quantize(Decimal('0.00')) == time_stamp.quantize(Decimal('0.00')):
                    source_frame_path = os.path.join(source_folder, f"{frame_id}.jpg")
                    destination_frame_path = os.path.join(destination_folder, f"{frame_id}.jpg")

                    # Check if the source frame file exists
                    if os.path.exists(source_frame_path):
                        # Copy the frame to the destination folder
                        shutil.copy2(source_frame_path, destination_frame_path)
                        print(f"Frame {frame_id} copied from {source_frame_path} to {destination_frame_path}")
                    else:
                        print(f"Source frame {frame_id} does not exist: {source_frame_path}")
                else:
                    print(f"Front_Came_Time and Time_Stamp do not match for frame {frame_id}")

# Example usage
csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
source_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye"
destination_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame"

copy_frames(csv_file_path, source_frames_folder, destination_frames_folder)

# %%
import csv
import shutil
import os
from decimal import Decimal, InvalidOperation

def copy_frames(csv_path, source_folder, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Read CSV file
    with open(csv_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        header = next(csv_reader)  # Get header row

        # Find the column indices for "Front_Came_Time", "Time_Stamp", and "Frame_Id"
        front_came_time_index = header.index("Front_Came_Time")
        time_stamp_index = header.index("Time_Stamp")
        frame_id_index = header.index("Frame_Id")

        previous_frame_id = None

        for row in csv_reader:
            if row[front_came_time_index]:
                try:
                    front_came_time = Decimal(row[front_came_time_index])
                    time_stamp = Decimal(row[time_stamp_index])
                except InvalidOperation:
                    print(f"Skipping row due to invalid decimal format: {row}")
                    continue

                frame_id = row[frame_id_index]

                # Check if Front_Came_Time matches up to two decimal places
                if front_came_time.quantize(Decimal('0.00')) == time_stamp.quantize(Decimal('0.00')):
                    source_frame_path = os.path.join(source_folder, f"{frame_id}.jpg")
                    destination_frame_path = os.path.join(destination_folder, f"{frame_id}.jpg")

                    # Check if the source frame file exists
                    if os.path.exists(source_frame_path):
                        # Copy the frame to the destination folder
                        shutil.copy2(source_frame_path, destination_frame_path)
                        print(f"Frame {frame_id} copied from {source_frame_path} to {destination_frame_path}")

                        # Update previous_frame_id for the next iteration
                        previous_frame_id = frame_id

                elif previous_frame_id:
                    # If Front_Came_Time doesn't match, use previous_frame_id and check the corresponding row
                    if front_came_time.quantize(Decimal('0.00')) == Decimal(row[time_stamp_index]).quantize(Decimal('0.00')):
                        source_frame_path = os.path.join(source_folder, f"{previous_frame_id}.jpg")
                        destination_frame_path = os.path.join(destination_folder, f"{previous_frame_id}.jpg")

                        # Check if the source frame file exists
                        if os.path.exists(source_frame_path):
                            # Copy the frame to the destination folder
                            shutil.copy2(source_frame_path, destination_frame_path)
                            print(f"Frame {previous_frame_id} copied from {source_frame_path} to {destination_frame_path}")

# Example usage
csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
source_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye"
destination_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame"


copy_frames(csv_file_path, source_frames_folder, destination_frames_folder)

# %%
import csv
import shutil
import os
from decimal import Decimal, InvalidOperation

def copy_frames(csv_path, source_folder, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Read CSV file
    with open(csv_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        header = next(csv_reader)  # Get header row

        # Find the column indices for "Front_Came_Time", "Time_Stamp", and "Frame_Id"
        front_came_time_index = header.index("Front_Came_Time")
        time_stamp_index = header.index("Time_Stamp")
        frame_id_index = header.index("Frame_Id")

        previous_frame_id = None

        for row in csv_reader:
            if row[front_came_time_index]:
                try:
                    front_came_time = Decimal(row[front_came_time_index])
                    time_stamp = Decimal(row[time_stamp_index])
                except InvalidOperation:
                    print(f"Skipping row due to invalid decimal format: {row}")
                    continue

                frame_id = row[frame_id_index]

                # Check if Front_Came_Time matches up to two decimal places
                if front_came_time.quantize(Decimal('0.00')) == time_stamp.quantize(Decimal('0.00')):
                    source_frame_path = os.path.join(source_folder, f"{frame_id}.jpg")
                    destination_frame_path = os.path.join(destination_folder, f"{frame_id}.jpg")

                    # Check if the source frame file exists
                    if os.path.exists(source_frame_path):
                        # Copy the frame to the destination folder
                        shutil.copy2(source_frame_path, destination_frame_path)
                        print(f"Frame {frame_id} copied from {source_frame_path} to {destination_frame_path}")

                        # Update previous_frame_id for the next iteration
                        previous_frame_id = frame_id

                elif previous_frame_id:
                    # If Front_Came_Time doesn't match, use previous_frame_id and check the corresponding row
                    if front_came_time.quantize(Decimal('0.00')) == Decimal(row[time_stamp_index]).quantize(Decimal('0.00')):
                        source_frame_path = os.path.join(source_folder, f"{frame_id}.jpg")
                        destination_frame_path = os.path.join(destination_folder, f"{frame_id}.jpg")

                        # Check if the source frame file exists
                        if os.path.exists(source_frame_path):
                            # Copy the frame to the destination folder
                            shutil.copy2(source_frame_path, destination_frame_path)
                            print(f"Frame {frame_id} copied from {source_frame_path} to {destination_frame_path}")

# Example usage
csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
source_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye"
destination_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame"



copy_frames(csv_file_path, source_frames_folder, destination_frames_folder)

# %%
import csv
import shutil
import os
from decimal import Decimal, InvalidOperation

def copy_frames(csv_path, source_folder, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Read CSV file
    with open(csv_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        header = next(csv_reader)  # Get header row

        # Find the column indices for "Front_Came_Time", "Time_Stamp", and "Frame_Id"
        front_came_time_index = header.index("Front_Came_Time")
        time_stamp_index = header.index("Time_Stamp")
        frame_id_index = header.index("Frame_Id")

        for row in csv_reader:
            if row[front_came_time_index]:
                try:
                    front_came_time = Decimal(row[front_came_time_index])
                except InvalidOperation:
                    print(f"Skipping row due to invalid decimal format: {row}")
                    continue

                frame_id = row[frame_id_index]

                # Check if Front_Came_Time matches up to two decimal places in subsequent rows
                for next_row in csv_reader:
                    try:
                        next_front_came_time = Decimal(next_row[front_came_time_index])
                    except InvalidOperation:
                        print(f"Skipping row due to invalid decimal format: {next_row}")
                        continue

                    # Check if Front_Came_Time matches up to two decimal places
                    if front_came_time.quantize(Decimal('0.00')) == next_front_came_time.quantize(Decimal('0.00')):
                        next_frame_id = next_row[frame_id_index]
                        source_frame_path = os.path.join(source_folder, f"{next_frame_id}.jpg")
                        destination_frame_path = os.path.join(destination_folder, f"{next_frame_id}.jpg")

                        # Check if the source frame file exists
                        if os.path.exists(source_frame_path):
                            # Copy the frame to the destination folder
                            shutil.copy2(source_frame_path, destination_frame_path)
                            print(f"Frame {next_frame_id} copied from {source_frame_path} to {destination_frame_path}")
                        else:
                            print(f"Source frame {next_frame_id} does not exist: {source_frame_path}")

# Example usage
csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
source_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\Left_Eye"
destination_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\Left_Eye_Frame"

copy_frames(csv_file_path, source_frames_folder, destination_frames_folder)

# %%
import csv
import shutil
import os
from decimal import Decimal, InvalidOperation

def copy_frames(csv_path, source_folder, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Read CSV file
    with open(csv_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file)
        header = next(csv_reader)  # Get header row

        # Find the column indices for "Front_Came_Time", "Time_Stamp", and "Frame_Id"
        front_came_time_index = header.index("Front_Came_Time")
        time_stamp_index = header.index("Time_Stamp")
        frame_id_index = header.index("Frame_Id")

        for row in csv_reader:
            front_came_time_str = row[front_came_time_index].strip()

            if front_came_time_str:
                try:
                    front_came_time = Decimal(front_came_time_str)
                except InvalidOperation:
                    print(f"Skipping row due to invalid decimal format: {row}")
                    continue

                frame_id = row[frame_id_index]

                # Check if Front_Came_Time matches up to two decimal places in subsequent rows
                for next_row in csv_reader:
                    next_front_came_time_str = next_row[front_came_time_index].strip()

                    if next_front_came_time_str:
                        try:
                            next_front_came_time = Decimal(next_front_came_time_str)
                        except InvalidOperation:
                            print(f"Skipping row due to invalid decimal format: {next_row}")
                            continue

                        # Check if Front_Came_Time matches up to two decimal places
                        if front_came_time.quantize(Decimal('0000000.00')) == next_front_came_time.quantize(Decimal('000000.00')):
                            next_frame_id = next_row[frame_id_index]
                            source_frame_path = os.path.join(source_folder, f"{next_frame_id}.jpg")
                            destination_frame_path = os.path.join(destination_folder, f"{next_frame_id}.jpg")

                            # Check if the source frame file exists
                            if os.path.exists(source_frame_path):
                                # Copy the frame to the destination folder
                                shutil.copy2(source_frame_path, destination_frame_path)
                                print(f"Frame {next_frame_id} copied from {source_frame_path} to {destination_frame_path}")
                            else:
                                print(f"Source frame {next_frame_id} does not exist: {source_frame_path}")

# Example usage
csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
source_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\Left_Eye"
destination_frames_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\Left_Eye_Frame"


copy_frames(csv_file_path, source_frames_folder, destination_frames_folder)

# %%
import os
import shutil
import pandas as pd

def copy_frames(csv_file_path, source_folder, destination_folder):
    # Read CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    # Iterate through each row in the DataFrame
    for index, row in df.iterrows():
        front_came_time = row['Front_Came_Time']
        time_stamp = row['Time_Stamp']
        frame_id = row['Frame_Id']

        # Check if the values in the first and third columns match up to two decimal places
        if round(front_came_time, 2) == round(time_stamp, 2):
            # Build the file paths for source and destination
            source_file_path = os.path.join(source_folder, f'{frame_id}.jpg')
            destination_file_path = os.path.join(destination_folder, f'{frame_id}.jpg')

            # Copy the frame from the source to the destination
            shutil.copy(source_file_path, destination_file_path)

if __name__ == "__main__":
    # Provide the paths to your CSV file, source folder, and destination folder
    sv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
    source_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye"
    destination_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame"


    # Call the function to copy frames based on the specified conditions
    copy_frames(csv_file_path, source_folder, destination_folder)

# %%
import os
import shutil
import pandas as pd

def copy_frames(csv_file_path, source_folder, destination_folder):
    # Read CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    # Iterate through each row in the DataFrame
    for index, row in df.iterrows():
        front_came_time = row['Front_Came_Time']
        time_stamp = row['Time_Stamp']
        frame_id = row['Frame_Id']

        # Check if the values in the first and third columns match up to two decimal places
        if round(front_came_time, 2) == round(time_stamp, 2):
            # Build the file paths for source and destination
            source_file_path = os.path.join(source_folder, f'{frame_id}.jpg')
            destination_file_path = os.path.join(destination_folder, f'{frame_id}.jpg')

            # Copy the frame from the source to the destination
            shutil.copy(source_file_path, destination_file_path)

if __name__ == "__main__":
    # Provide the paths to your CSV file, source folder, and destination folder
    csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
    source_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\\Left_Eye"
    destination_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\\Left_Eye_Frame"

    # Call the function to copy frames based on the specified conditions
    copy_frames(csv_file_path, source_folder, destination_folder)

# %%
import os
import shutil
import pandas as pd

def copy_frames(csv_file_path, source_folder, destination_folder):
    # Read CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    # Iterate through each value in the first column
    for index, row in df.iterrows():
        front_came_time = row['Front_Came_Time']
        frame_id = row['Frame_Id']

        # Find the corresponding row in the third column where the condition is met
        match_row = df[df['Time_Stamp'].apply(lambda x: round(x, 2)) == round(front_came_time, 2)].iloc[0]

        # Extract information from the matched row
        time_stamp = match_row['Time_Stamp']
        matched_frame_id = match_row['Frame_Id']

        # Check if the values in the first and third columns match up to two decimal places
        if round(front_came_time, 2) == round(time_stamp, 2):
            # Build the file paths for source and destination
            source_file_path = os.path.join(source_folder, f'{matched_frame_id}.jpg')
            destination_file_path = os.path.join(destination_folder, f'{matched_frame_id}.jpg')

            # Copy the frame from the source to the destination
            shutil.copy(source_file_path, destination_file_path)

if __name__ == "__main__":
    # Provide the paths to your CSV file, source folder, and destination folder
    csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
    source_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye"
    destination_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame"

    # Call the function to copy frames based on the specified conditions
    copy_frames(csv_file_path, source_folder, destination_folder)

# %%
import os
import shutil
import pandas as pd

def copy_frames(csv_file_path, source_folder, destination_folder):
    # Read CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    # Iterate through each value in the first column
    for index, row in df.iterrows():
        front_came_time = row['Front_Came_Time']
        frame_id = row['Frame_Id']

        # Find the corresponding row in the third column where the condition is met
        match_row = df[df['Time_Stamp'].apply(lambda x: round(x, 2)) == round(front_came_time, 2)].iloc[0]

        # Extract information from the matched row
        time_stamp = match_row['Time_Stamp']
        matched_frame_id = match_row['Frame_Id']

        # Check if the values in the first and third columns match up to two decimal places
        if round(front_came_time, 2) == round(time_stamp, 2):
            # Build the file paths for source and destination
            source_file_path = os.path.join(source_folder, f'{matched_frame_id}.jpg')
            destination_file_path = os.path.join(destination_folder, f'{matched_frame_id}.jpg')

            # Copy the frame from the source to the destination
            shutil.copy(source_file_path, destination_file_path)

if __name__ == "__main__":
    # Provide the paths to your CSV file, source folder, and destination folder
    csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
    source_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye/"
    destination_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame/"

    # Call the function to copy frames based on the specified conditions
    copy_frames(csv_file_path, source_folder, destination_folder)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-1446c3f8a00f> in <module>
#      35
#      36     # Call the function to copy frames based on the specified conditions
# ---> 37     copy_frames(csv_file_path, source_folder, destination_folder)
#
# <ipython-input-5-1446c3f8a00f> in copy_frames(csv_file_path, source_folder, destination_folder)
#      26
#      27             # Copy the frame from the source to the destination
# ---> 28             shutil.copy(source_file_path, destination_file_path)
#      29
#      30 if __name__ == "__main__":
#
# ~\anaconda3\lib\shutil.py in copy(src, dst, follow_symlinks)
#     413     if os.path.isdir(dst):
#     414         dst = os.path.join(dst, os.path.basename(src))
# --> 415     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     416     copymode(src, dst, follow_symlinks=follow_symlinks)
#     417     return dst
#
# ~\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     259         os.symlink(os.readlink(src), dst)
#     260     else:
# --> 261         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     262             # macOS
#     263             if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye/53574.0.jpg'

# %%
import os
import shutil
import pandas as pd

def copy_frames(csv_file_path, source_folder, destination_folder):
    # Read CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    # Iterate through each value in the first column
    for index, row in df.iterrows():
        front_came_time = row['Front_Came_Time']
        frame_id = str(row['Frame_Id'])  # Convert frame_id to string

        # Find the corresponding row in the third column where the condition is met
        match_row = df[df['Time_Stamp'].apply(lambda x: round(x, 2)) == round(front_came_time, 2)].iloc[0]

        # Extract information from the matched row
        time_stamp = match_row['Time_Stamp']
        matched_frame_id = str(match_row['Frame_Id'])  # Convert matched_frame_id to string

        # Check if the values in the first and third columns match up to two decimal places
        if round(front_came_time, 2) == round(time_stamp, 2):
            # Build the file paths for source and destination
            source_file_path = os.path.join(source_folder, f'{frame_id}.jpg')
            destination_file_path = os.path.join(destination_folder, f'{matched_frame_id}.jpg')

            # Copy the frame from the source to the destination
            shutil.copy(source_file_path, destination_file_path)

if __name__ == "__main__":
    # Provide the paths to your CSV file, source folder, and destination folder
    csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
    source_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\\Left_Eye"
    destination_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\\Left_Eye_Frame"

    # Call the function to copy frames based on the specified conditions
    copy_frames(csv_file_path, source_folder, destination_folder)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-8c6e074bd9d6> in <module>
#      35
#      36     # Call the function to copy frames based on the specified conditions
# ---> 37     copy_frames(csv_file_path, source_folder, destination_folder)
#
# <ipython-input-6-8c6e074bd9d6> in copy_frames(csv_file_path, source_folder, destination_folder)
#      26
#      27             # Copy the frame from the source to the destination
# ---> 28             shutil.copy(source_file_path, destination_file_path)
#      29
#      30 if __name__ == "__main__":
#
# ~\anaconda3\lib\shutil.py in copy(src, dst, follow_symlinks)
#     413     if os.path.isdir(dst):
#     414         dst = os.path.join(dst, os.path.basename(src))
# --> 415     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     416     copymode(src, dst, follow_symlinks=follow_symlinks)
#     417     return dst
#
# ~\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     259         os.symlink(os.readlink(src), dst)
#     260     else:
# --> 261         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     262             # macOS
#     263             if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\\Left_Eye\\1.0.jpg'

# %%
import os
import shutil
import pandas as pd

def copy_frames(csv_file_path, source_folder, destination_folder):
    # Read CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    # Iterate through each value in the first column
    for index, row in df.iterrows():
        front_came_time = row['Front_Came_Time']
        frame_id = str(row['Frame_Id'])  # Convert frame_id to string

        # Find the corresponding row in the third column where the condition is met
        match_row = df[df['Time_Stamp'].apply(lambda x: round(x, 2)) == round(front_came_time, 2)].iloc[0]

        # Extract information from the matched row
        time_stamp = match_row['Time_Stamp']
        matched_frame_id = str(match_row['Frame_Id'])  # Convert matched_frame_id to string

        # Check if the values in the first and third columns match up to two decimal places
        if round(front_came_time, 2) == round(time_stamp, 2):
            # Build the file paths for source and destination
            source_file_path = os.path.join(source_folder, f'{frame_id}.jpg')
            destination_file_path = os.path.join(destination_folder, f'{matched_frame_id}.jpg')

            # Print the file paths for debugging
            print(f"Source: {source_file_path}, Destination: {destination_file_path}")

            # Copy the frame from the source to the destination
            shutil.copy(source_file_path, destination_file_path)

if __name__ == "__main__":
    # Provide the paths to your CSV file, source folder, and destination folder
    csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
    source_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\\Left_Eye"
    destination_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\\Left_Eye_Frame"

    # Call the function to copy frames based on the specified conditions
    copy_frames(csv_file_path, source_folder, destination_folder)
# Out:
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\Left_Eye\1.0.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\Left_Eye_Frame\53574.0.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-df51a7198a26> in <module>
#      38
#      39     # Call the function to copy frames based on the specified conditions
# ---> 40     copy_frames(csv_file_path, source_folder, destination_folder)
#
# <ipython-input-7-df51a7198a26> in copy_frames(csv_file_path, source_folder, destination_folder)
#      29
#      30             # Copy the frame from the source to the destination
# ---> 31             shutil.copy(source_file_path, destination_file_path)
#      32
#      33 if __name__ == "__main__":
#
# ~\anaconda3\lib\shutil.py in copy(src, dst, follow_symlinks)
#     413     if os.path.isdir(dst):
#     414         dst = os.path.join(dst, os.path.basename(src))
# --> 415     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     416     copymode(src, dst, follow_symlinks=follow_symlinks)
#     417     return dst
#
# ~\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     259         os.symlink(os.readlink(src), dst)
#     260     else:
# --> 261         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     262             # macOS
#     263             if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd\\Left_Eye\\1.0.jpg'

# %%
import os
import shutil
import pandas as pd

def copy_frames(csv_file_path, source_folder, destination_folder):
    # Read CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    # Iterate through each value in the first column
    for index, row in df.iterrows():
        front_came_time = row['Front_Came_Time']
        frame_id = str(int(row['Frame_Id']))  # Convert frame_id to string, remove '.0'

        # Find the corresponding row in the third column where the condition is met
        match_row = df[df['Time_Stamp'].apply(lambda x: round(x, 2)) == round(front_came_time, 2)].iloc[0]

        # Extract information from the matched row
        time_stamp = match_row['Time_Stamp']
        matched_frame_id = str(int(match_row['Frame_Id']))  # Convert matched_frame_id to string, remove '.0'

        # Check if the values in the first and third columns match up to two decimal places
        if round(front_came_time, 2) == round(time_stamp, 2):
            # Build the file paths for source and destination
            source_file_path = os.path.join(source_folder, f'{matched_frame_id}.jpg')
            destination_file_path = os.path.join(destination_folder, f'{matched_frame_id}.jpg')

            # Print the file paths for debugging
            print(f"Source: {source_file_path}, Destination: {destination_file_path}")

            # Copy the frame from the source to the destination
            shutil.copy(source_file_path, destination_file_path)

if __name__ == "__main__":
    # Provide the paths to your CSV file, source folder, and destination folder
    csv_file_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-16T16-37-28.935894-1-recordings/2023-05-11_16-06-01-e9ea58dd/eye0_timestamps.csv"
    source_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye"
    destination_folder = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame"

    # Call the function to copy frames based on the specified conditions
    copy_frames(csv_file_path, source_folder, destination_folder)
# Out:
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\53931.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\53931.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\53971.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\53971.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54011.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54011.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54051.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54051.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54091.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54091.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54131.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54131.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54171.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54171.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54211.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54211.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54251.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54251.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54290.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54290.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54330.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54330.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54370.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54370.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54410.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54410.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54450.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54450.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54490.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54490.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54530.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54530.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54570.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54570.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54610.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54610.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54650.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54650.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54690.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54690.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54730.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54730.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54770.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54770.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54810.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54810.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54850.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54850.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54890.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54890.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54930.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54930.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\54970.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\54970.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55010.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55010.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55049.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55049.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55089.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55089.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55129.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55129.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55169.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55169.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55209.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55209.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55249.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55249.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55289.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55289.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55329.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55329.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55369.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55369.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55409.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55409.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55449.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55449.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55489.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55489.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55529.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55529.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55569.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55569.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55609.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55609.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55649.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55649.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55689.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55689.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55729.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55729.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55769.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55769.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55808.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55808.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55848.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55848.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55888.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55888.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55928.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55928.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\55968.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\55968.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56008.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56008.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56048.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56048.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56088.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56088.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56128.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56128.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56168.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56168.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56208.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56208.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56248.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56248.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56288.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56288.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56328.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56328.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56368.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56368.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56407.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56407.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56447.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56447.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56487.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56487.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56527.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56527.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56566.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56566.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56606.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56606.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56646.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56646.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56686.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56686.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56726.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56726.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56766.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56766.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56806.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56806.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56846.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56846.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56886.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56886.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56926.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56926.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\56966.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\56966.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57006.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57006.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57046.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57046.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57086.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57086.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57126.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57126.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57166.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57166.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57206.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57206.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57246.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57246.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57286.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57286.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57326.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57326.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57365.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57365.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57405.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57405.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57445.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57445.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57485.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57485.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57524.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57524.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57563.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57563.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57603.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57603.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57642.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57642.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57682.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57682.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57722.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57722.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57762.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57762.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57802.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57802.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57842.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57842.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57882.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57882.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57922.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57922.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\57962.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\57962.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58002.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58002.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58041.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58041.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58081.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58081.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58120.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58120.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58160.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58160.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58200.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58200.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58240.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58240.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58280.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58280.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58320.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58320.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58360.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58360.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58400.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58400.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58440.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58440.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58480.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58480.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58520.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58520.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58560.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58560.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58600.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58600.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58640.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58640.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58680.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58680.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58719.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58719.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58759.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58759.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58797.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58797.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58837.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58837.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58876.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58876.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58916.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58916.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58956.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58956.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\58996.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\58996.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\59036.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\59036.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\59076.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\59076.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\59116.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\59116.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\59156.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\59156.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\59196.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\59196.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\59236.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\59236.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\59276.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\59276.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\59316.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\59316.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\59356.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\59356.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\59396.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\59396.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\59436.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\59436.jpg
# ...
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64269.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64269.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64309.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64309.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64349.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64349.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64389.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64389.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64429.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64429.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64469.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64469.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64509.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64509.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64549.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64549.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64589.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64589.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64629.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64629.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64669.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64669.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64709.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64709.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64749.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64749.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64789.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64789.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64829.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64829.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64869.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64869.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64909.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64909.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64949.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64949.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\64988.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\64988.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65028.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65028.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65068.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65068.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65108.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65108.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65148.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65148.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65188.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65188.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65228.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65228.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65268.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65268.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65308.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65308.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65348.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65348.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65388.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65388.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65428.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65428.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65468.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65468.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65508.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65508.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65548.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65548.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65588.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65588.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65628.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65628.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65668.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65668.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65708.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65708.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65747.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65747.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65787.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65787.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65827.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65827.jpg
# Source: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye\65867.jpg, Destination: E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Left_Eye_Frame\65867.jpg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-1d20e1f74c90> in <module>
#      38
#      39     # Call the function to copy frames based on the specified conditions
# ---> 40     copy_frames(csv_file_path, source_folder, destination_folder)
#
# <ipython-input-16-1d20e1f74c90> in copy_frames(csv_file_path, source_folder, destination_folder)
#      13
#      14         # Find the corresponding row in the third column where the condition is met
# ---> 15         match_row = df[df['Time_Stamp'].apply(lambda x: round(x, 2)) == round(front_came_time, 2)].iloc[0]
#      16
#      17         # Extract information from the matched row
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
#    1436         if key >= len_axis or key < -len_axis:
# -> 1437             raise IndexError("single positional indexer is out-of-bounds")
#    1438
#    1439     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
import os
import shutil
import pandas as pd

def copy_frames(csv_file_path, source_folder, destination_folder):
    # Read CSV file into a pandas DataFrame
    df = pd.read_csv(csv_file_path)

    # Iterate through each value in the first column
    for index, row in df.iterrows():
        front_came_time = row['Front_Came_Time']
        frame_id = str(int(row['Frame_Id']))  # Convert frame_id to string, remove '.0'

        # Find the corresponding row in the third column where the condition is met
        match_row = df[df['Time_Stamp'].apply(lambda x: round(x, 2)) == round(front_came_time, 2)].iloc[0]

        # Extract information from the matched row
        time_stamp = match_row['Time_Stamp']
        matched_frame_id = str(int(match_row['Frame_Id']))  # Convert matched_frame_id to string, remove '.0'

        # Check if the values in the first and third columns match up to two decimal places
        if round(front_came_time, 2) == round(time_stamp, 2):
            # Build the file paths for source and destination
            source_file_path = os.path.join(source_folder, f'{matched_frame_id}.jpg')
            destination_file_path = os.path.join(destination_folder, f'{matched_frame_id}.jpg')

            # Print the file paths for debugging
            print(f"Source: {source_file_path}, Destination: {destination_file_path}")

            # Copy the frame from the source to the destination
            shutil.copy(source_file_path, destination_file_path)

if __name__ == "__main__":
    # Provide the paths to your CSV file, source folder, and destination folder
    csv_file_path ="E:/Driver_Gaze_Data/P4320230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-39-06.829160-1-recordings/2023-05-28_18-01-05-82c6b903/exports/000/eye1_timestamps.csv"
    source_folder = "E:/Driver_Gaze_Data/P4320230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-39-06.829160-1-recordings/2023-05-28_18-01-05-82c6b903/exports/000/Eye1"
    destination_folder = "E:/Driver_Gaze_Data/P4320230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-39-06.829160-1-recordings/2023-05-28_18-01-05-82c6b903/exports/000/Eye1_Frame"

    # Call the function to copy frames based on the specified conditions
    copy_frames(csv_file_path, source_folder, destination_folder)
# Out:
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\24731.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\24731.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\24771.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\24771.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\24811.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\24811.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\24851.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\24851.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\24891.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\24891.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\24930.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\24930.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\24970.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\24970.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25010.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25010.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25050.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25050.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25090.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25090.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25130.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25130.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25170.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25170.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25210.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25210.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25250.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25250.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25290.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25290.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25330.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25330.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25370.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25370.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25410.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25410.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25450.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25450.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25490.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25490.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25530.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25530.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25570.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25570.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25610.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25610.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25650.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25650.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25689.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25689.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25729.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25729.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25769.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25769.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25809.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25809.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25849.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25849.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25889.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25889.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25929.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25929.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\25969.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\25969.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26009.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26009.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26049.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26049.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26089.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26089.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26129.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26129.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26169.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26169.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26209.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26209.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26249.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26249.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26289.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26289.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26329.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26329.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26369.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26369.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26409.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26409.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26448.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26448.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26488.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26488.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26528.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26528.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26568.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26568.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26608.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26608.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26648.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26648.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26688.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26688.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26728.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26728.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26768.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26768.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26808.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26808.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26848.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26848.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26888.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26888.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26928.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26928.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\26968.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\26968.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27008.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27008.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27048.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27048.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27087.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27087.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27128.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27128.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27168.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27168.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27207.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27207.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27247.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27247.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27287.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27287.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27327.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27327.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27367.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27367.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27407.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27407.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27447.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27447.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27487.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27487.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27527.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27527.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27567.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27567.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27607.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27607.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27647.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27647.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27687.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27687.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27727.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27727.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27767.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27767.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27807.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27807.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27847.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27847.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27887.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27887.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27927.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27927.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\27966.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\27966.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28006.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28006.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28046.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28046.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28086.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28086.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28126.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28126.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28166.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28166.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28206.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28206.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28246.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28246.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28286.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28286.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28326.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28326.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28366.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28366.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28406.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28406.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28443.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28443.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28483.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28483.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28523.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28523.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28563.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28563.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28603.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28603.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\28643.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\28643.jpg
# ...
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35554.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35554.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35594.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35594.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35633.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35633.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35673.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35673.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35713.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35713.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35753.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35753.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35793.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35793.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35833.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35833.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35873.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35873.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35913.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35913.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35953.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35953.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\35993.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\35993.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36033.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36033.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36073.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36073.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36113.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36113.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36153.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36153.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36193.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36193.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36233.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36233.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36273.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36273.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36313.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36313.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36353.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36353.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36392.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36392.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36432.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36432.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36472.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36472.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36512.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36512.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36552.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36552.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36592.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36592.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36632.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36632.jpg
# Source: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1\36672.jpg, Destination: E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye1_Frame\36672.jpg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-6572a2d7267d> in <module>
#      38
#      39     # Call the function to copy frames based on the specified conditions
# ---> 40     copy_frames(csv_file_path, source_folder, destination_folder)
#
# <ipython-input-4-6572a2d7267d> in copy_frames(csv_file_path, source_folder, destination_folder)
#      13
#      14         # Find the corresponding row in the third column where the condition is met
# ---> 15         match_row = df[df['Time_Stamp'].apply(lambda x: round(x, 2)) == round(front_came_time, 2)].iloc[0]
#      16
#      17         # Extract information from the matched row
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
#    1436         if key >= len_axis or key < -len_axis:
# -> 1437             raise IndexError("single positional indexer is out-of-bounds")
#    1438
#    1439     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# # Binary Conversion of Image

# %%
import cv2
import os

# Function to convert image to binary and apply the specified condition
def process_image(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each file in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(".jpg"):
            # Read the grayscale image
            img_path = os.path.join(input_folder, filename)
            img_gray = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

            # Apply binary thresholding
            _, binary_img = cv2.threshold(img_gray, 25, 255, cv2.THRESH_BINARY)

            # Apply the condition to set pixels in the specified range to white
            binary_img[:, 150:200] = 255
            #binary_img[:, 0:60] = 255
            binary_img[0:60, :] = 255

            # Save the binary image to the output folder
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, binary_img)

# Specify the input and output folders
input_folder = "E:/Driver_Gaze_Data/P1620230526D2/Eyetracker_Data/pupil-cloud-download-2024-01-17T06-39-04.314270-1-recordings/2023-05-26_17-48-15-eff8dfc4/exports/000/Eye0_Rotate_Frame"
output_folder = "E:/Driver_Gaze_Data/P1620230526D2/Eyetracker_Data/pupil-cloud-download-2024-01-17T06-39-04.314270-1-recordings/2023-05-26_17-48-15-eff8dfc4/exports/000/Eye0_Pupil_Binary_Frame"

# Process images
process_image(input_folder, output_folder)

# %%
import cv2
import os
import csv
import numpy as np

# Function to find the center coordinate of the black portion and save results in CSV
def process_image(input_folder, csv_filename):
    # Open a CSV file to write the results
    with open(csv_filename, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(['Image', 'Center_X', 'Center_Y'])

        # Iterate through each file in the input folder
        for filename in os.listdir(input_folder):
            if filename.endswith(".jpg"):
                # Read the binary image
                img_path = os.path.join(input_folder, filename)
                binary_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

                # Find the center coordinate of the black portion
                center_x, center_y = find_center_of_black(binary_img)

                # Save the results in the CSV file
                csv_writer.writerow([filename, center_x, center_y])

# Function to find the center coordinate of the black portion in a binary image
def find_center_of_black(binary_img):
    # Find the indices of black pixels
    black_pixels = np.column_stack(np.where(binary_img == 0))

    # Calculate the center coordinate as the mean of the black pixel coordinates
    if len(black_pixels) > 0:
        center_x, center_y = np.mean(black_pixels, axis=0, dtype=int)
    else:
        center_x, center_y = -1, -1

    return center_x, center_y

# Specify the input folder and CSV file
input_folder = "E:/Driver_Gaze_Data/P1720230527D3/Eyetracker_Data/pupil-cloud-download-2024-01-17T06-39-11.844244-1-recordings/2023-05-27_11-12-55-adbbdcfd/exports/000/Eye0_Pupil_Binary_Frame"
csv_filename = "E:/Driver_Gaze_Data/P1720230527D3/Eyetracker_Data/pupil-cloud-download-2024-01-17T06-39-11.844244-1-recordings/2023-05-27_11-12-55-adbbdcfd/exports/000/Eye0_Pupil_Binary_Frame/Eye0_Pupil_detected_binary_result.csv"
#csv_filename = "E:/Driver_Gaze_Data/P3820230528D4/Eyetracker_Data/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/pupil-cloud-download-2024-01-17T10-38-29.703144-1-recordings/2023-05-28_15-36-20-2f61a46c/exports/000/Eye0_Pupil_Binary_Frame/Ey1.csv"

# Process images and save results in CSV
process_image(input_folder, csv_filename)
