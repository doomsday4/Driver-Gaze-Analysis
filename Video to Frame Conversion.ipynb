# %% [markdown]
# # Video to frame conversion

# %%
import cv2
vidcap = cv2.VideoCapture("E:/Driver_Gaze_Data/P1220230526D2/Eyetracker_Data/pupil-cloud-download-2024-01-17T06-22-04.370809-1-recordings/2023-05-26_15-35-36-54e72a5d/exports/000/eye1.mp4")
#vidcap = cv2.VideoCapture('D:/Perungulathursection/DRONE03/DAY 1/MORNING/CARD 2 - 11.00 to 11.30/DJI_0001.MP4')
success,image = vidcap.read()
count = 1
while success:
    cv2.imwrite("E:/Driver_Gaze_Data/P1220230526D2/Eyetracker_Data/pupil-cloud-download-2024-01-17T06-22-04.370809-1-recordings/2023-05-26_15-35-36-54e72a5d/exports/000/Eye1/%d.jpg" % count, image) # save frame as JPEG file
    success,image = vidcap.read()
    print('Read a new frame: ', success)
    count += 1

# %% [markdown]
# # Video Frame_Rate Estimation

# %%
import cv2
import pandas as pd


video_file = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/PI left v1 ps1.mp4"


# Open the video file
video = cv2.VideoCapture(video_file)

# Set the current frame rate
current_fps = video.get(cv2.CAP_PROP_FPS)
print(current_fps)
# Out:
# 199.67046838674952

# %% [markdown]
# # Video to frame conversion using frame rate

# %%
import cv2

# Define the video file path
#video_path ="E:/Driver_Gaze_Data_Processing/P4120230528D4/Eyetracker_Frame/ae5aae3c_0.0-465.792.mp4"
video_path = "/Users/apple/Downloads/Sem6/ugp/2023-06-09_11-06-35-f692baa9/eye1.mp4"
output_path = "/Users/apple/Downloads/Sem6/ugp/output/eye1/"


# Define the desired frame rate for extraction
frame_rate = 18000  # For example, extracting every 2 seconds

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get the frames per second (fps) of the video
fps = cap.get(cv2.CAP_PROP_FPS)

# Calculate the frame interval based on desired frame rate
frame_interval = int(fps / frame_rate)

frame_count = 0

while True:
    ret, frame = cap.read()

    # Break the loop if no more frames are available
    if not ret:
        break

    # Extract frames at the desired frame rate
    if frame_count % frame_interval == 0:
        # Save or process the extracted frame here
        frame_filename = output_path+f'frame{frame_count}.jpg'
        cv2.imwrite(frame_filename, frame)

    frame_count += 1

# Release the video capture object
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # video trimming

# %%
import cv2

input_file = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/PI right v1 ps1.mp4"
output_file = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/P2_PI right v1 ps1.mp4"
start_time_minutes = 4   # Start time in minutes
start_time_seconds = 27.5  # Start time in seconds
duration_seconds = 60     # Duration in seconds

cap = cv2.VideoCapture(input_file)
frame_rate = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

start_time_total_seconds = start_time_minutes * 60 + start_time_seconds
start_frame = int(start_time_total_seconds * frame_rate)
end_frame = start_frame + int(duration_seconds * frame_rate)

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_file, fourcc, frame_rate, (frame_width, frame_height))

cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

for frame_index in range(start_frame, end_frame):
    ret, frame = cap.read()
    if not ret:
        break
    out.write(frame)

cap.release()
out.release()

# %% [markdown]
# # Frame Extraction with fixed frame rate

# %%
import cv2

def extract_frames(video_path, output_folder, frame_rate):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the desired frame interval based on the fixed frame rate
    interval = int(fps / frame_rate)

    # Create the output folder if it doesn't exist
    import os
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through frames and extract based on the frame rate
    for i in range(0, total_frames, interval):
        # Set the frame position
        cap.set(cv2.CAP_PROP_POS_FRAMES, i)

        # Read the frame
        ret, frame = cap.read()

        # Save the frame to the output folder
        if ret:
            frame_filename = f"{output_folder}/frame_{i:01d}.jpg"
            cv2.imwrite(frame_filename, frame)
            print(f"Frame {i} saved as {frame_filename}")

    # Release the video capture object
    cap.release()

if __name__ == "__main__":
    # Replace 'input_video.mp4' with the path to your input video file
    input_video_path = 'C:/Users/Pavan Kumar Sharma/Downloads/pupil-cloud-download-2024-01-05T06-07-56.675903-1-recordings/2023-05-11_16-46-45-273bb776/PI right v1 ps1.mp4'

    # Replace 'output_frames' with the desired output folder
    output_folder = 'C:/Users/Pavan Kumar Sharma/Downloads/pupil-cloud-download-2024-01-05T06-07-56.675903-1-recordings/2023-05-11_16-46-45-273bb776/Right_Eye_Frames'

    # Replace 2 with your desired fixed frame rate (frames per second)
    fixed_frame_rate = 20

    # Call the function to extract frames
    extract_frames(input_video_path, output_folder, fixed_frame_rate)

# %%
import cv2
import os

def extract_frames(video_path, output_folder, frame_rate):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Get video properties
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the desired frame interval based on the fixed frame rate
    interval = int(fps / frame_rate)

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through frames and extract based on the frame rate
    frame_count = 1
    for i in range(0, total_frames, interval):
        # Set the frame position
        cap.set(cv2.CAP_PROP_POS_FRAMES, i)

        # Read the frame
        ret, frame = cap.read()

        # Save the frame to the output folder
        if ret:
            frame_filename = f"{output_folder}/frame{frame_count:1d}.jpg"
            cv2.imwrite(frame_filename, frame)
            print(f"Frame {frame_count} saved as {frame_filename}")
            frame_count += 1

    # Release the video capture object
    cap.release()

if __name__ == "__main__":
    # Replace 'input_video.mp4' with the path to your input video file
    input_video_path = 'C:/Users/Pavan Kumar Sharma/Downloads/pupil-cloud-download-2024-01-05T06-07-56.675903-1-recordings/2023-05-11_16-46-45-273bb776/PI left v1 ps1.mp4'
    # Replace 'output_frames' with the desired output folder
    output_folder = 'C:/Users/Pavan Kumar Sharma/Downloads/pupil-cloud-download-2024-01-05T06-07-56.675903-1-recordings/2023-05-11_16-46-45-273bb776/Left_Eye_Frames'

    # Replace 2 with your desired fixed frame rate (frames per second)
    fixed_frame_rate = 20

    # Call the function to extract frames
    extract_frames(input_video_path, output_folder, fixed_frame_rate)

# %% [markdown]
# # Frames rotating

# %%
import os
import cv2

def rotate_frames(input_folder, output_folder):
    # Create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate through each file in the input folder
    for filename in os.listdir(input_folder):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        # Read the image
        frame = cv2.imread(input_path)

        if frame is not None:
            # Rotate the frame by 270 degrees
            rotated_frame = cv2.rotate(frame, cv2.ROTATE_90_COUNTERCLOCKWISE)

            # Save the rotated frame to the output folder
            cv2.imwrite(output_path, rotated_frame)
            print(f"Rotated and saved: {output_path}")

if __name__ == "__main__":
    input_folder = "/Users/apple/Downloads/Sem6/ugp/output/eye1/"
    output_folder = "/Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/"

    rotate_frames(input_folder, output_folder)
# Out:
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame49335.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame10240.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame56215.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame30190.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame103105.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame94140.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame108050.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame128380.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame117170.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame80135.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame42260.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame14740.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame52715.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame34490.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame118525.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame129920.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame107405.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame90440.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame122875.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame113470.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame84435.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame79590.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame59640.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame48995.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame46760.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame19270.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame26080.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame40305.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame82050.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame115015.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame89105.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame96025.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame101060.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame54370.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame12325.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame22580.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame13985.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame44605.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame8190.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame99470.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame86550.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame111515.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame120910.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame92525.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame105560.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame134965.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame50670.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame16625.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame88555.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame6195.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame131835.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame97475.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame100430.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame55720.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame13775.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame18620.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame50880.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame41755.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame61485.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame125840.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame134795.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame83400.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame114445.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame2495.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame93175.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame104130.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame28085.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame51220.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame17275.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame45255.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame65185.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame98020.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame130295.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame87100.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame110145.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame109400.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame116520.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame81565.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame127925.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame43630.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame48765.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame77595.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame11610.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame57645.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame46990.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame102555.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame95510.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame122685.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame133950.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame112020.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame85065.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame58210.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame47330.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame73095.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame15310.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame53345.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame119175.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame106055.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame91010.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame126385.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame34335.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame72360.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame1605.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame127070.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame540.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame118280.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame133005.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame84390.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame66315.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame20340.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame79235.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame30635.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame76660.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame78895.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame69740.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame49490.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame5305.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame123570.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame85930.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame112975.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame91945.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame106900.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame80690.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame119820.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame128425.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame62615.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame35995.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame24640.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame22225.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame64270.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame131160.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame8635.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame92280.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame125115.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame3760.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame70205.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame36250.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame16180.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame29370.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame26725.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame60770.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame39605.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame104865.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame93820.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame96780.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame110810.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame87855.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame121415.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame7260.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame98975.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame74705.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame32750.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame23885.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame12480.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame124545.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame2330.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame104695.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame115940.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame82905.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame51585.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame71655.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame60980.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame37600.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame28720.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame23675.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame65620.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame130530.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame101935.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame96970.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame98785.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame89850.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame9265.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame120045.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame6630.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame100395.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame55085.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame75355.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame33300.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame27375.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame61320.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame38255.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame18185.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame134030.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame3990.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame94815.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame103850.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame112785.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame132455.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame76890.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame67745.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame21710.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame47495.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame78665.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame35765.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame73730.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame80860.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame117825.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame126420.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame108905.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame116285.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame129075.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame63245.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame25210.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame43195.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame31265.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame77230.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame68310.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame4755.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame122120.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame105010.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame92055.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame50300.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame16355.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame36085.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame44375.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame99100.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame111065.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame86020.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame89475.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame130915.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame101510.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame96555.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame54600.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame12655.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame32585.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame19700.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame40675.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame124960.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame115565.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame82520.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame84145.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame113100.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame59330.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame20195.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame46210.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame14230.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame52265.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame118055.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame90130.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame107175.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame795.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame108520.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame80445.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame117400.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame126805.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame24495.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame42710.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame15890.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame58990.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame49645.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame69595.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame10730.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame56765.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame94430.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame103475.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame132870.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame15660.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame53635.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame119405.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame128800.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame91560.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame106525.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame123955.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame132680.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame85515.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame112550.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame58760.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame56995.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame47640.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame67590.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame48215.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame11360.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame57335.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame4580.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame95060.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame102025.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame109170.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame965.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame81015.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame116050.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame43340.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame63090.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame45725.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame98550.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame110435.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame87470.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame121830.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame104440.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame93405.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame124790.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame71480.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame51750.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame40885.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame17705.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame18350.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame38080.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame41225.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame114135.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame83170.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame88025.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame100140.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame97105.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame120290.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame75180.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame55250.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame13205.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame7710.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame121165.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame74275.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame32220.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame26255.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame60200.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame39375.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame82285.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame3210.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame125465.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame83825.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame114860.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame70775.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame36720.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame29600.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame33880.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame22755.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame64700.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame131410.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame97850.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame100815.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame86785.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame88970.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame8345.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame128155.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame108285.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame62365.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame24330.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame30345.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame76310.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame10095.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame69230.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame94395.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame123000.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame5675.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame102970.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame95935.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame133575.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame66665.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame20630.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame59495.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame79745.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame68890.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame34645.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame25990.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame72610.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame14595.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame90695.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame116905.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame81940.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame127500.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame1375.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame109825.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame57490.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame31715.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame77740.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame66895.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame68660.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame122450.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame4225.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame102780.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame113855.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame84810.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame107820.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame90865.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame118900.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame129505.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame63735.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame25760.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame53190.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame35215.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame73240.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame126150.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame106280.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame132125.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame5885.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame67235.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame21260.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame78315.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame27605.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame70985.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame61650.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame41580.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame38725.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame92900.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame105945.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame114690.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame134540.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame86975.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame111930.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame6340.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame120535.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame99855.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame88780.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame75625.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame33670.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame23305.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame65350.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame45080.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame110390.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame130040.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame9715.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame2640.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame124035.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame71325.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame37370.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame28250.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame94550.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame103515.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame132910.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame30580.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame10650.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame56605.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame49725.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame42670.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame80525.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame117560.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame126965.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame128790.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame108440.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame90050.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame107015.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame118135.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame34080.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame14350.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame52305.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame46370.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame59250.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame79180.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame84025.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame113060.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame124800.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame115405.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame82440.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame17895.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame40715.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame26490.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame19660.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame54760.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame12735.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame130875.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame101470.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame96435.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame89515.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame111105.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame86140.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame99060.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame8580.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame44215.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame22190.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame50260.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame16235.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame105170.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame92135.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame55330.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame13365.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame100020.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame97065.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame6585.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame88145.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame114055.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame83010.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame134385.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame61095.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame41345.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame18230.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame51630.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame17665.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame19890.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame28495.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame104520.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame93565.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame2085.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame110555.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame87510.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame85.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame121950.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame130685.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame98430.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame65595.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame54990.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame45645.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame43220.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame805.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame81175.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame116130.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame109010.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame122295.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame95100.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame102145.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame11200.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame57255.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame77185.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame48375.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame47720.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame58600.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame123835.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame85475.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame112430.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame126795.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame91400.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame106445.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame119565.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame128960.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame15700.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame53755.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame42880.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame73485.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame109945.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame118690.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame116865.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame81820.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame127460.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame150.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame1215.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame34725.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame72770.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame79625.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame66705.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame31885.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame20750.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame102810.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame95855.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame84780.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame133415.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame123160.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame5715.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame49080.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame69350.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame30225.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame76270.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame62205.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame24250.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame128035.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame80280.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame88810.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame8225.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame131570.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame97930.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame100975.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame22635.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame64660.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame29760.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame16590.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame70615.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame36640.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame27995.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame3370.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame125505.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame92690.jpg
# ...
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame22200.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame64255.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame70220.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame36275.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame29355.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame125130.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame3745.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame85915.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame112950.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame103685.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame5320.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame123555.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame30610.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame67990.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame76645.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame56595.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame69765.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame62630.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame24665.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame91960.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame106925.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame128400.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame119805.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame107385.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame1620.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame127055.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame565.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame34310.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame72345.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame52095.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame66330.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame20365.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame79210.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame4980.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame133020.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame63260.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame25235.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame109380.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame129050.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame4770.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame122105.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame95290.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame11190.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame31240.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame77215.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame68335.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame67760.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame21735.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame69995.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame78640.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame58590.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame132470.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame94830.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame103875.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame126405.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame80845.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame117800.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame91790.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame108920.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame15490.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame24895.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame35740.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame73715.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame75370.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame33325.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame120060.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame6615.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame83380.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame134015.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame27350.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame61305.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame38270.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame71670.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame37625.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame28705.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame115965.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame82920.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame124560.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame2315.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame87680.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame101910.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame96955.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame130515.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame9240.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame89875.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame23650.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame32985.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame65605.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame99455.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame120935.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame86575.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame111530.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame44620.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame41980.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame50655.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame16600.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame70585.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame134940.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame125695.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame92500.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame105545.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame82075.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame115030.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame39185.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame19255.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame40320.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame54355.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame12300.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame74085.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame89120.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame121395.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame96000.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame101045.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame129905.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame118500.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame107420.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame90465.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame1185.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame14765.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame52730.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame59665.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame66495.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame46745.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame57890.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame113455.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame84410.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame133785.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame122850.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame103120.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame94165.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame5485.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame49310.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame10265.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame56230.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame62195.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame42245.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame108075.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame117155.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame80110.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame58235.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame47315.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame21090.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame112005.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame85040.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame119150.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame106070.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame91035.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame15335.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame53360.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame43615.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame14995.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame25590.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame109425.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame127900.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame116505.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame81540.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame133975.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame102570.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame95535.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame68490.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame48740.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame59895.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame11635.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame57660.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame37180.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame51205.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame17250.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame93150.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame104115.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame98005.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame87125.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame110160.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame45270.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame33480.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame55705.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame13750.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame88570.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame97450.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame100415.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame131810.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame83425.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame114460.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame125865.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame18605.jpg
# Rotated and saved: /Users/apple/Downloads/Sem6/ugp/output/eye1_rotated/frame41770.jpg

# %% [markdown]
# # Video Length

# %%
import cv2

def get_video_length(file_path):
    try:
        cap = cv2.VideoCapture(file_path)
        fps = cap.get(cv2.CAP_PROP_FPS)
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        duration = frame_count / fps
        cap.release()
        return duration
    except Exception as e:
        print(f"Error: {e}")
        return None

# Replace 'your_video_file.mp4' with the path to your video file
video_path = 'E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/PI right v1 ps1.mp4'

length = get_video_length(video_path)

if length is not None:
    print(f"The length of the video is: {length} seconds")
else:
    print("Unable to determine the length of the video.")
# Out:
# The length of the video is: 725.4604333333333 seconds

# %% [markdown]
# # Extract frame from fixed time interval

# %%
import cv2

def extract_frames(video_path, output_path, start_time, interval, duration):
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("Error: Couldn't open the video file.")
        return

    # Set the start time
    cap.set(cv2.CAP_PROP_POS_MSEC, start_time * 1000)

    frame_count = 0
    while True:
        ret, frame = cap.read()

        if not ret or frame_count * interval > duration:
            break

        frame_count += 1

        # Save the frame
        output_frame_path = f"{output_path}/frame{frame_count}.jpg"
        cv2.imwrite(output_frame_path, frame)

        # Move to the next frame
        cap.set(cv2.CAP_PROP_POS_MSEC, (start_time + frame_count * interval) * 1000)

    cap.release()

if __name__ == "__main__":
    video_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/PI right v1 ps1.mp4"
    output_path = "E:/Driver_Gaze_Data/P220230511D1/Eyetracker_Data/pupil-cloud-download-2024-01-14T14-00-29.489121-1-recordings/2023-05-11_16-06-01-e9ea58dd/Right"
    start_time = 267.5    # seconds
    interval = 0.2       # seconds
    duration = 60        # seconds (one minute)

    extract_frames(video_path, output_path, start_time, interval, duration)

# %%
import cv2
vidcap = cv2.VideoCapture('E:/Driver_Gaze_Data/P720230526D2/Exp/1683801340456800474_cam_1.mp4')
#vidcap = cv2.VideoCapture('D:/Perungulathursection/DRONE03/DAY 1/MORNING/CARD 2 - 11.00 to 11.30/DJI_0001.MP4')
success,image = vidcap.read()
count = 0
while success:
    cv2.imwrite('E:/Driver_Gaze_Data_Processing/P720230526D2/Front_Camera_Frame/frame%d.jpg' % count, image) # save frame as JPEG file
    success,image = vidcap.read()
    print('Read a new frame: ', success)
    count += 1

# %%
import pandas as pd
import os
import shutil
from datetime import datetime

# Path to the first CSV file containing timestamps
csv1_path = "D:/Academics/PHD Admission/IIT Kanpur/Data Collection/Driver_Face/Driver_Gaze_Data/P320230511/Ground_Truth_GAZE-OVERLAY_Ground_Truth_Generation/2023-05-11_16-46-45-273bb776/world_timestamps(UTC).csv"

# Path to the second CSV file containing timestamps and frame IDs
csv2_path = "D:/Academics/PHD Admission/IIT Kanpur/Data Collection/Driver_Face/Driver_Gaze_Data/P320230511/Exp1/Cam_1_Frame/Time_Stamps(UTC) Cam_1_Frame.csv"


# Path to the folder containing the video frames
frames_folder = "D:/Academics/PHD Admission/IIT Kanpur/Data Collection/Driver_Face/Driver_Gaze_Data/P320230511/Exp1/Cam_1_Frame/"

# Path to the destination folder to copy matching frames
destination_folder = "D:/Academics/PHD Admission/IIT Kanpur/Data Collection/Driver_Face/Driver_Gaze_Data/P320230511/Exp1/Cam1/"

# Load the CSV files into pandas DataFrames
csv1_data = pd.read_csv(csv1_path)
csv2_data = pd.read_csv(csv2_path)

# Iterate over each row in the first CSV file
for _, row_csv1 in csv1_data.iterrows():
    timestamp_csv1 = datetime.strptime(row_csv1['IST Time'], '%Y-%m-%d %H:%M:%S.%f%z')

    # Find the nearest matching timestamp in the second CSV file
    closest_frame = None
    closest_time_diff = float('inf')

    for _, row_csv2 in csv2_data.iterrows():
        timestamp_csv2 = datetime.strptime(row_csv2['IST Time'], '%Y-%m-%d %H:%M:%S.%f%z')
        time_diff = abs(timestamp_csv1 - timestamp_csv2)

        if time_diff < closest_time_diff:
            closest_time_diff = time_diff
            closest_frame = row_csv2['Frame_ID']

    if closest_frame is not None:
        # Construct the frame filename based on the frame ID
        frame_filename =  str(closest_frame) + '.jpg'

        # Source path of the matching frame
        source_frame_path = os.path.join(frames_folder, frame_filename)

        # Destination path to copy the matching frame
        destination_frame_path = os.path.join(destination_folder, frame_filename)

        # Copy the matching frame to the destination folder
        shutil.copyfile(source_frame_path, destination_frame_path)

# %%
import pandas as pd
import os
from datetime import datetime

# Step 1: Read the first CSV file with UTC timestamps
df_timestamps = pd.read_csv("D:/Academics/PHD Admission/IIT Kanpur/Data Collection/Driver_Face/Driver_Gaze_Data/P320230511/Ground_Truth_GAZE-OVERLAY_Ground_Truth_Generation/2023-05-11_16-46-45-273bb776/world_timestamps(UTC).csv")


# Step 2: Read the second CSV file with frame IDs and timestamps
df_frames = pd.read_csv("D:/Academics/PHD Admission/IIT Kanpur/Data Collection/Driver_Face/Driver_Gaze_Data/P320230511/Exp1/Cam_1_Frame/Time_Stamps(UTC) Cam_1_Frame.csv")

# Step 3: Iterate over each row in the first DataFrame
for index, row in df_timestamps.iterrows():
    target_timestamp = datetime.strptime(row['IST Time'], '%Y-%m-%d %H:%M:%S.%f%z')

    # Step 4: Find the nearest timestamp in the second DataFrame
    nearest_timestamp = df_frames['IST Time'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S.%f%z')).\
        iloc[(df_frames['IST Time'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S.%f%z')) - target_timestamp).abs().idxmin()]
    
    # Step 5: Retrieve the corresponding frame ID and move the frame file to a new folder
    frame_id = df_frames.loc[df_frames['timestamp'] == nearest_timestamp, 'frame_id'].values[0]
    frame_file = f'{frame_id}.jpg'  # Assuming frames are in JPG format
    source_path = f'D:\Academics\PHD Admission\IIT Kanpur\Data Collection\Driver_Face\Driver_Gaze_Data\P320230511\Exp1\Cam_1_Frame/{frame_file}'  # Update with the actual source folder path
    destination_folder = f'D:\Academics\PHD Admission\IIT Kanpur\Data Collection\Driver_Face\Driver_Gaze_Data\P320230511\Exp1\Cam1/{frame_id}'  # Update with the destination folder path
    os.makedirs(destination_folder, exist_ok=True)
    destination_path = f'{destination_folder}/{frame_file}'
    os.rename(source_path, destination_path)

# %%
import pandas as pd
import os
from datetime import datetime

# Step 1: Read the first CSV file with UTC timestamps
df_timestamps = pd.read_csv("D:/Academics/PHD Admission/IIT Kanpur/Data Collection/Driver_Face/Driver_Gaze_Data/P320230511/Ground_Truth_GAZE-OVERLAY_Ground_Truth_Generation/2023-05-11_16-46-45-273bb776/world_timestamps(UTC).csv")


# Step 2: Read the second CSV file with frame IDs and timestamps
df_frames = pd.read_csv("D:/Academics/PHD Admission/IIT Kanpur/Data Collection/Driver_Face/Driver_Gaze_Data/P320230511/Exp1/Cam_1_Frame/Time_Stamps(UTC) Cam_1_Frame.csv")

# Step 3: Iterate over each row in the first DataFrame
for index, row in df_timestamps.iterrows():
    target_timestamp = datetime.strptime(row['IST Time'], '%Y-%m-%d %H:%M:%S.%f%z')

    # Step 4: Find the nearest timestamp in the second DataFrame
    nearest_timestamp = df_frames['IST Time'].apply(lambda x: datetime.strptime(x.replace(':', ''), '%Y-%m-%d %H:%M:%S.%f%z')).\
        iloc[(df_frames['IST Time'].apply(lambda x: datetime.strptime(x.replace(':', ''), '%Y-%m-%d %H:%M:%S.%f%z')) - target_timestamp).abs().idxmin()]
    
    # Step 5: Retrieve the corresponding frame ID and move the frame file to a new folder
    frame_id = df_frames.loc[df_frames['timestamp'] == nearest_timestamp, 'frame_id'].values[0]
    frame_file = f'{frame_id}.jpg'  # Assuming frames are in JPG format
    source_path = f'D:\Academics\PHD Admission\IIT Kanpur\Data Collection\Driver_Face\Driver_Gaze_Data\P320230511\Exp1\Cam_1_Frame/{frame_file}'  # Update with the actual source folder path
    destination_folder = f'D:\Academics\PHD Admission\IIT Kanpur\Data Collection\Driver_Face\Driver_Gaze_Data\P320230511\Exp1\Cam1/{frame_id}'  # Update with the destination folder path
    os.makedirs(destination_folder, exist_ok=True)
    destination_path = f'{destination_folder}/{frame_file}'
    os.rename(source_path, destination_path)

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('D:/Academics/PHD Admission/IIT Kanpur/Data Collection/Driver_Face/Driver_Gaze_Data/P320230511/Exp1/Time_Stamps(UTC) Cam_1_Frame.csv')

# Remove the timezone offset from the timestamp column
df['IST Time'] = df['IST Time'].str.replace(r'\+\d{2}:\d{2}$', '', regex=True)

# Display the modified DataFrame
print(df)
# Convert the timestamp column to string
df['IST Time'] = df['IST Time'].astype(str)
# Save the modified DataFrame to a new CSV file
df.to_csv('D:/Academics/PHD Admission/IIT Kanpur/Data Collection/Driver_Face/Driver_Gaze_Data/P320230511/Exp1/Time_Stamps(UTC) Cam_1_Frame(new).csv', index=False, float_format='%.9f')

# %%
import datetime
import time

timestamp = '2023-05-11 16:46:39.190953178+05:30'
datetime_obj = datetime.datetime.strptime(timestamp, '%Y-%m-%d %H:%M:%S.%f%z')
epoch = int(datetime_obj.timestamp())

print(epoch)

# %%
import datetime

timestamp = '2023-05-11 16:46:39.390953178+05:30'
timestamp_without_microsec = timestamp.split('.')[0]  # Remove microseconds
timestamp_without_offset = timestamp_without_microsec.rsplit('+', 1)[0]  # Remove timezone offset
datetime_obj = datetime.datetime.strptime(timestamp_without_offset, '%Y-%m-%d %H:%M:%S')

epoch = int(datetime_obj.timestamp() * 1e9)

print(epoch)
# Out:
# 1683803799000000000

# %%
import cv2

def extract_frames(video_path):
    # Open the video file
    video = cv2.VideoCapture(video_path)
    frame_rate = video.get(cv2.CAP_PROP_FPS)

    # Set the initial frame count and timestamp
    frame_count = 0
    timestamp = 0

    while True:
        # Read the next frame
        ret, frame = video.read()

        if not ret:
            break

        # Check if it's time to extract a frame
        if frame_count % int(frame_rate) == 0:
            # Save the frame with the corresponding timestamp
            frame_name = f"{timestamp}.jpg"
            cv2.imwrite(frame_name, frame)
            print(f"Saved frame: {frame_name}")

        # Increment the frame count and timestamp
        frame_count += 1
        timestamp += 1

    # Release the video file
    video.release()

# Example usage
video_path = "E:/Driver_Gaze_Data/P420230526D2/Eyetracker_Data/2023-05-26_10-45-19-8e15fb3e/4a276385_0.0-682.736.mp4"
extract_frames(video_path)

# %% [markdown]
# # Merge multiple CSV file into single CSV

# %%
# importing libraries
import pandas as pd
import glob
import os
  
# merging the files
joined_files = os.path.join("E:/Driver_Gaze_Data_Processing/gt_speak_Merge", "gt_speak_merge*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)
  
# Finally, the files are joined
df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
print(df)

# %%
# importing libraries
import pandas as pd
import glob
import os
  
# merging the files
joined_files = os.path.join("E:/Driver_Gaze_Data_Processing/Manual_Annotation/Manual Annotation(Two Annotator)", "P*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)
  
# Finally, the files are joined
df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
print(df)

# %%
df.to_csv('E:/Driver_Gaze_Data_Processing/Manual_Annotation/Manual Annotation(Two Annotator)/merge.csv')

# %%
import pandas as pd
df=pd.read_csv("E:/Driver_Gaze_Data_Processing/gt_speak_Merge/merge.csv")
#df.drop(['remove'],axis=1,inplace=True)
df.head()
# Out:
#                               GT_File GT_Class        Frame Speak_File  \
# 0  Ground_Truth_Classes/6/frame_0.jpg        6  frame_0.jpg        NaN
# 1  Ground_Truth_Classes/6/frame_1.jpg        6  frame_1.jpg        NaN
# 2  Ground_Truth_Classes/6/frame_2.jpg        6  frame_2.jpg        NaN
# 3  Ground_Truth_Classes/6/frame_3.jpg        6  frame_3.jpg        NaN
# 4  Ground_Truth_Classes/6/frame_4.jpg        6  frame_4.jpg        NaN
#
#   Org_Speak_Class  Speak_Class  Speak_Class_Counter  Frame_ID
# 0             NaN          NaN                  NaN         0
# 1             NaN          NaN                  NaN         1
# 2             NaN          NaN                  NaN         2
# 3             NaN          NaN                  NaN         3
# 4             NaN          NaN                  NaN         4

# %%
#df.to_csv('E:/Driver_Gaze_Data_Processing/gt_speak_Merge/merge1.csv')

# %%
df.dropna(subset=['Speak_File', 'Org_Speak_Class', 'Speak_Class', 'Speak_Class_Counter'], inplace = True)
df.head()
# Out:
#                                 GT_File GT_Class         Frame  \
# 44  Ground_Truth_Classes/6/frame_44.jpg        6  frame_44.jpg
# 45  Ground_Truth_Classes/6/frame_45.jpg        6  frame_45.jpg
# 46  Ground_Truth_Classes/6/frame_46.jpg        6  frame_46.jpg
# 47  Ground_Truth_Classes/6/frame_47.jpg        6  frame_47.jpg
# 48  Ground_Truth_Classes/6/frame_48.jpg        6  frame_48.jpg
#
#                       Speak_File Org_Speak_Class  Speak_Class  \
# 44  Speak2Label/6_1/frame_44.jpg             6_1          6.0
# 45  Speak2Label/6_1/frame_45.jpg             6_1          6.0
# 46  Speak2Label/6_1/frame_46.jpg             6_1          6.0
# 47  Speak2Label/6_1/frame_47.jpg             6_1          6.0
# 48  Speak2Label/6_1/frame_48.jpg             6_1          6.0
#
#     Speak_Class_Counter  Frame_ID
# 44                  1.0        44
# 45                  1.0        45
# 46                  1.0        46
# 47                  1.0        47
# 48                  1.0        48

# %%
df.drop(['GT_File', 'Frame', 'Speak_File'], axis=1, inplace=True)
df
# Out:
#       GT_Class Org_Speak_Class  Speak_Class  Speak_Class_Counter  Frame_ID
# 44           6             6_1          6.0                  1.0        44
# 45           6             6_1          6.0                  1.0        45
# 46           6             6_1          6.0                  1.0        46
# 47           6             6_1          6.0                  1.0        47
# 48           6             6_1          6.0                  1.0        48
# ...        ...             ...          ...                  ...       ...
# 66426    Other             1_4          1.0                  4.0      1578
# 66427    Other             1_4          1.0                  4.0      1579
# 66480        6             2_4          2.0                  4.0      1632
# 66481        6             2_4          2.0                  4.0      1633
# 66482        6             2_4          2.0                  4.0      1634
#
# [18523 rows x 5 columns]

# %%
df.to_csv('E:/Driver_Gaze_Data_Processing/gt_speak_Merge/Gt_merge_confusion.csv')

# %% [markdown]
# # Draw confusion matrix

# %%
plot_color_gradients('Perceptually Uniform Sequential',
                     ['viridis', 'plasma', 'inferno', 'magma', 'cividis'])

plot_color_gradients('Sequential',
                     ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
                      'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
                      'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn'])

# %%
#Confusion matrix for moving pointer based method
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns

# Define custom colors
custom_colors = ['#FF5733', '#33FF57', '#3366FF', '#FF33CC']  # Add more colors as needed

# Create a custom colormap
custom_cmap = mcolors.ListedColormap(custom_colors)

data= pd.read_csv("E:/Driver_Gaze_Data_Processing/Moving_Pointer/Moving_Pointer_Frame_Wise/CSV_File/MP_Frame_P4320230528D4.csv")
confusion_matrix = pd.crosstab(data['GT_Class'], data['Pointer_Class'], rownames=['Ground_Truth_Class'], colnames=['Pointer_Class'])
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix, annot=True, cmap='Oranges', fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Pointer_Class')
plt.ylabel('Ground_Truth_Class')
# Save the figure
plt.savefig('E:/Driver_Gaze_Data_Processing/Moving_Pointer/Moving_Pointer_Frame_Wise/CSV_File/Accuracy Analysis/Confusion Matrix/MP_Confusion_Matrix_P43.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns

# Define custom colors
custom_colors = ['#FF5733', '#33FF57', '#3366FF', '#FF33CC']  # Add more colors as needed

# Create a custom colormap
custom_cmap = mcolors.ListedColormap(custom_colors)

data= pd.read_csv("E:/Driver_Gaze_Data_Processing/Speak2label_New/GT_Merge(P10_M0)/gt_speak_merge43(P10_M0).csv")
confusion_matrix = pd.crosstab(data['GT_Class'], data['Speak_Class'], rownames=['Ground_Truth_Class'], colnames=['Speak_Class'])
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix, annot=True, cmap='Oranges', fmt='d')
plt.title('Confusion Matrix_(P10_M0)')
plt.xlabel('Speak_Class')
plt.ylabel('Ground_Truth_Class')
# Save the figure
plt.savefig('E:/Driver_Gaze_Data_Processing/Speak2label_New/Accuracy_Calculation/Analysis of P10_M/Confusion_Matrix_(P10_M0)_P43.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns

# Define custom colors
custom_colors = ['#FF5733', '#33FF57', '#3366FF', '#FF33CC']  # Add more colors as needed

# Create a custom colormap
custom_cmap = mcolors.ListedColormap(custom_colors)

data= pd.read_csv('E:/Driver_Gaze_Data_Processing/Manual_Annotation/Frame_wise_Manual_Annotation/Frame_Wise_Manual_Annotation.csv')
confusion_matrix = pd.crosstab(data['GT_Class'], data['Annotated_Class'], rownames=['Ground_Truth_Class'], colnames=['Annotated_Class'])
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix, annot=True, cmap='Oranges', fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Annotated_Class')
plt.ylabel('Ground_Truth_Class')
# Save the figure
plt.savefig('E:/Driver_Gaze_Data_Processing/Manual_Annotation/Frame_wise_Manual_Annotation/confusion_matrix.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns

# Define custom colors
custom_colors = ['#FF5733', '#33FF57', '#3366FF', '#FF33CC']  # Add more colors as needed

# Create a custom colormap
custom_cmap = mcolors.ListedColormap(custom_colors)

data= pd.read_csv("E:/Driver_Gaze_Data_Processing/Manual_Annotation/Manual Annotation(Two Annotator)/P1920230527D3_Frame.csv")
confusion_matrix = pd.crosstab(data['GT_Class'], data['Class_A1'], rownames=['Ground_Truth_Class'], colnames=['Annotator_Class'])
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix, annot=True, cmap='Oranges', fmt='d')
plt.title('Confusion Matrix Annotator1 P19')
plt.xlabel('Annotator_Class')
plt.ylabel('Ground_Truth_Class')
# Save the figure
plt.savefig('E:/Driver_Gaze_Data_Processing/Manual_Annotation/Manual Annotation(Two Annotator)/Confusion_Matrix/MA_Confusion_Matrix_A1_P19.png')
plt.show()

# %%
import pandas as pd
import glob
data = pd.read_csv('E:/Driver_Gaze_Data_Processing/gt_speak_Merge/merge1.csv')
data
# Out:
#                                          GT_File GT_Class           Frame  \
# 0             Ground_Truth_Classes/6/frame_0.jpg        6     frame_0.jpg
# 1             Ground_Truth_Classes/6/frame_1.jpg        6     frame_1.jpg
# 2             Ground_Truth_Classes/6/frame_2.jpg        6     frame_2.jpg
# 3             Ground_Truth_Classes/6/frame_3.jpg        6     frame_3.jpg
# 4             Ground_Truth_Classes/6/frame_4.jpg        6     frame_4.jpg
# ...                                          ...      ...             ...
# 66572  Ground_Truth_Classes/Other/frame_1724.jpg    Other  frame_1724.jpg
# 66573  Ground_Truth_Classes/Other/frame_1725.jpg    Other  frame_1725.jpg
# 66574  Ground_Truth_Classes/Other/frame_1726.jpg    Other  frame_1726.jpg
# 66575  Ground_Truth_Classes/Other/frame_1727.jpg    Other  frame_1727.jpg
# 66576  Ground_Truth_Classes/Other/frame_1728.jpg    Other  frame_1728.jpg
#
#       Speak_File Org_Speak_Class  Speak_Class  Speak_Class_Counter  Frame_ID
# 0            NaN             NaN          NaN                  NaN         0
# 1            NaN             NaN          NaN                  NaN         1
# 2            NaN             NaN          NaN                  NaN         2
# 3            NaN             NaN          NaN                  NaN         3
# 4            NaN             NaN          NaN                  NaN         4
# ...          ...             ...          ...                  ...       ...
# 66572        NaN             NaN          NaN                  NaN      1724
# 66573        NaN             NaN          NaN                  NaN      1725
# 66574        NaN             NaN          NaN                  NaN      1726
# 66575        NaN             NaN          NaN                  NaN      1727
# 66576        NaN             NaN          NaN                  NaN      1728
#
# [66577 rows x 8 columns]

# %%
data.drop(['GT_File', 'Frame', 'Speak_File', 'Org_Speak_Class', 'Speak_Class_Counter', 'Frame_ID'], axis=1, inplace=True)
data

# %%
data.to_csv('E:/Driver_Gaze_Data_Processing/gt_speak_Merge/max_frequency.csv')

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('E:/Driver_Gaze_Data_Processing/gt_speak_Merge/max_frequency.csv')

# Iterate through the DataFrame
for i in range(len(df)):
    if pd.isnull(df.at[i, 'Speak_Class']):  # Check if the cell is empty
        # Calculate the range of rows to consider above and below the empty cell
        start_idx = max(0, i - 10)
        end_idx = min(len(df), i + 11)
        
        # Get non-empty values in the range
        valid_values = df.loc[start_idx:end_idx, 'Speak_Class'].dropna()
        
        # If there are valid values, fill the empty cell
        if not valid_values.empty:
            df.at[i, 'Speak_Class'] = valid_values.iloc[0]

# Save the updated DataFrame to a new CSV file
df.to_csv('E:/Driver_Gaze_Data_Processing/gt_speak_Merge/filled_data.csv', index=False)

# %% [markdown]
# # Remove missing value in rows

# %%
import pandas as pd
import glob
df = pd.read_csv('E:/Driver_Gaze_Data_Processing/gt_speak_Merge/max_frequency(accuracy).csv')
df.dropna(subset=['Speak_Class'], inplace = True)
df.head()
df.to_csv('E:/Driver_Gaze_Data_Processing/gt_speak_Merge/max_frequency(accuracy1).csv')

# %% [markdown]
# # Find most common match

# %%
df = pd.read_csv('E:/Driver_Gaze_Data_Processing/gt_speak_Merge/max_frequency(accuracy1).csv')
df
# Out:
#       GT_Class  Speak_Class
# 0            6            6
# 1            6            6
# 2            6            6
# 3            6            6
# 4            6            6
# ...        ...          ...
# 35283        6            2
# 35284        6            2
# 35285        6            2
# 35286        6            2
# 35287        6            2
#
# [35288 rows x 2 columns]

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('E:/Driver_Gaze_Data_Processing/gt_speak_Merge/max_frequency(accuracy1).csv')

# Initialize variables to keep track of the current sequence
current_sequence_value = None
current_sequence_count = 0
matching_count = 0
non_matching_count = 0

# Iterate through each row
for index, row in df.iterrows():
    column1_value = row['GT_Class']
    column2_value = row['Speak_Class']
    
    if current_sequence_value is None:
        current_sequence_value = column2_value
        current_sequence_count = 1
    elif column2_value == current_sequence_value:
        current_sequence_count += 1
    else:
        # Compare column1_value with current_sequence_value
        if column1_value == current_sequence_value:
            matching_count += current_sequence_count
        else:
            non_matching_count += current_sequence_count
        
        current_sequence_value = column2_value
        current_sequence_count = 1

# Handle the last sequence
if current_sequence_value is not None:
    if column1_value == current_sequence_value:
        matching_count += current_sequence_count
    else:
        non_matching_count += current_sequence_count

# Determine which count is greater
if matching_count >= non_matching_count:
    print(f'Matching count is greater: {matching_count}')
else:
    print(f'Non-matching count is greater: {non_matching_count}')

# Print the corresponding value from Column2
print(f'Corresponding Column2 value: {current_sequence_value}')
# Out:
# Non-matching count is greater: 35288
# Corresponding Column2 value: 2

# %%
import csv
from collections import Counter

# Read the input CSV file
input_file = 'E:/Driver_Gaze_Data_Processing/gt_speak_Merge/max_frequency(accuracy1).csv'
output_file = 'E:/Driver_Gaze_Data_Processing/gt_speak_Merge/output.csv'

class_mapping = {}  # To store the mapping of class values to their corresponding max class in column 2

# Read the CSV file and process the data
with open(input_file, 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip header row

    current_class = None
    current_counter = Counter()

    for row in reader:
        gt_class = int(row[0])
        speak_class = int(row[1])

        if gt_class != current_class:
            if current_class is not None:
                max_speak_class = current_counter.most_common(1)[0][0]
                class_mapping[current_class] = max_speak_class
                current_counter.clear()

            current_class = gt_class

        current_counter[speak_class] += 1

    # Handle the last class
    if current_class is not None:
        max_speak_class = current_counter.most_common(1)[0][0]
        class_mapping[current_class] = max_speak_class

# Write the output to a new CSV file
with open(output_file, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['GT_Class', 'Speak_Class'])

    for gt_class, speak_class in class_mapping.items():
        writer.writerow([gt_class, speak_class])

print("Output CSV file written successfully.")

# %%
import csv
from collections import Counter

# Read the input CSV file
input_file = 'E:/Driver_Gaze_Data_Processing/gt_speak_Merge/max_frequency(accuracy1).csv'
output_file = 'E:/Driver_Gaze_Data_Processing/gt_speak_Merge/output.csv'

class_mapping = {}  # To store the mapping of class values to their corresponding max class in column 2

# Read the CSV file and process the data
with open(input_file, 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip header row

    current_class = None
    current_counter = Counter()

    for row in reader:
        try:
            gt_class = int(row[0])
        except ValueError:
            continue  # Skip rows with non-numeric GT_Class
        speak_class = int(row[1])

        if gt_class != current_class:
            if current_class is not None:
                max_speak_class = current_counter.most_common(1)[0][0]
                class_mapping[current_class] = max_speak_class
                current_counter.clear()

            current_class = gt_class

        current_counter[speak_class] += 1

    # Handle the last class
    if current_class is not None:
        max_speak_class = current_counter.most_common(1)[0][0]
        class_mapping[current_class] = max_speak_class

# Write the output to a new CSV file
with open(output_file, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['GT_Class', 'Speak_Class'])

    for gt_class, speak_class in class_mapping.items():
        writer.writerow([gt_class, speak_class])

print("Output CSV file written successfully.")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns

# Define custom colors
custom_colors = ['#FF5733', '#33FF57', '#3366FF', '#FF33CC']  # Add more colors as needed

# Create a custom colormap
custom_cmap = mcolors.ListedColormap(custom_colors)

data= pd.read_csv("E:/Driver_Gaze_Data_Processing/P1820230527D3/Speak2Label/Discrete_Gaze_Classes_Eyetracker(20)/gt_speak_merge18(P0_M0).csv")
confusion_matrix = pd.crosstab(data['GT_Class'], data['Speak_Class'], rownames=['Ground_Truth_Class'], colnames=['Speak_Class'])
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_matrix, annot=True, cmap='Oranges', fmt='d')
plt.title('Confusion Matrix_(P0_M0)_P18')
plt.xlabel('Speak_Class')
plt.ylabel('Ground_Truth_Class')
# Save the figure
plt.savefig('E:/Driver_Gaze_Data_Processing/P1820230527D3/Speak2Label/Discrete_Gaze_Classes_Eyetracker(20)/Confusion_Matrix_(P0_M0)_18.png')
plt.show()
